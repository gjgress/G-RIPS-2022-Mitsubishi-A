# %%
# load dependencies'
import concurrent.futures
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape
import osmnx as ox
import networkx as nx
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
from urllib.parse import urljoin
from shapely.geometry import Point, LineString, Polygon
import pyproj 
import mm_utils
from function_util import *
from IMP import IMP
from SMP1 import SMP1
from SMP2 import SMP2
from FIS1 import FIS1
from FIS2 import FIS2
from FIS3 import *
import warnings
warnings.filterwarnings("ignore")

# %%
# load all the data 
gdf_utm = pd.read_pickle('gdf_utm.pkl')
edges_utm = pd.read_pickle('edges_utm.pkl')
nodes_utm = pd.read_pickle('nodes_utm.pkl')

# select error bound 
err_size = 38
# select cut off point for smp1, for use 60 following Quddus paper
cutoff = 60
# select number of no match needed to break iteration 
no_match_max = 3

# weight perpendicular distance more 
wt_matrix = build_matrix3(rule_3 = 1.5, rule_8 = 1.2)

# intialize no match counter 
no_match = 0 
# initialize matched trajectory list
matched_point_list = []
# initialize matched edge list 
matched_edge_list = []
# initialize SMP1 result list 
res_list =[]
# initialize counter for matched_list 
count = 0

point_index = 0

# Run IMP Algorithm to find first point 
point_index, curr_edge = IMP(point_index, gdf_utm, edges_utm, 7)

curr_edge['method'] = ['IMP']
#store current edge 
matched_edge_list.append(curr_edge)

# matched current location with current edge 
curr_loc = gdf_utm.iloc[[point_index]]
matched_point = point_matching(curr_loc, curr_edge.iloc[0])
# find longitude and latitude for last matched data
matched_point['lon_lat'] = matched_point.to_crs({'init': 'epsg:4326'})
matched_point['method'] = ['IMP']
# update previous matched position
last_matched = matched_point

# store matched point 
matched_point_list.append(matched_point)

# move to the next iteration with for loop
start_iter = point_index + 1


for point_index in range(start_iter, len(gdf_utm)):    
    # update last location 
    prev_loc = gdf_utm.iloc[[point_index - 1]]

    # update current location 
    curr_loc = gdf_utm.iloc[[point_index]]

    # perform SMP1 
    res = SMP1(curr_loc, curr_edge, prev_loc, last_matched, nodes_utm, edges_utm, gdf_utm)
    # store result list
    res_list.append(res)

    # decide whether vehicle is entering junction or not cut off 
    if res >= cutoff and res < 99:
        # vehicle is not entering a new edge, matched edge doesnt change
        # update matched edge list 
        print(['entering SMP1 at iteration'], point_index)
        curr_edge['method'] = ['SMP1']
        matched_edge_list.append(curr_edge)
        # update matched point
        matched_point = point_matching(curr_loc, curr_edge.iloc[0])
        # find longitude and latitude for last matched data
        matched_point['lon_lat'] = matched_point.to_crs({'init': 'epsg:4326'})
        matched_point['method'] = ['SMP1']
        # store matched point 
        matched_point_list.append(matched_point)
        # update previous matched position
        last_matched = matched_point
    elif res < cutoff:
        prev_edge = curr_edge
        # SMP1 detect vehicle is entering new edge, perform SMP 2 to update current edge
        edge_candidate = SMP2(curr_loc, curr_edge, prev_loc, last_matched, err_size, nodes_utm, edges_utm, gdf_utm, wt_matrix = wt_matrix)

        if edge_candidate is None:
            print(['No edge can be matched at trajectory number', point_index])
            no_match += 1
        else:
            print(['entering SMP2 at iteration'], point_index)
            curr_edge = edge_candidate
            curr_edge['method'] = ['SMP2']
            # curr_edge['prev_end_node'] = prev_edge.index[0][1]
            # there is no more matched edge, break the loop 
            matched_edge_list.append(curr_edge)
            # update matched point
            matched_point = point_matching(curr_loc, curr_edge.iloc[0])
            # find longitude and latitude for last matched data
            matched_point['lon_lat'] = matched_point.to_crs({'init': 'epsg:4326'})
            matched_point['method'] = ['SMP2']
            # store matched point 
            matched_point_list.append(matched_point)
            # update previous matched position
            last_matched = matched_point

    if no_match == no_match_max:
        # stop iteration when there number of no match is exceeded
        break

    # update count 
    count +=  1
# Out:
# ['edges found at iteration number', 1]
# ['edges found at iteration number', 2]
# ['edges found at iteration number', 3]
# ['edges found at iteration number', 4]
# ['edges found at iteration number', 5]
# ['edges found at iteration number', 6]
# ['edges found at iteration number', 7]
# ['edges found at iteration number', 8]
# ['edges found at iteration number', 9]
# ['edges found at iteration number', 10]
# ['edges found at iteration number', 11]
# ['edges found at iteration number', 12]
# ['edges found at iteration number', 13]
# ['edges found at iteration number', 14]
# ['edges found at iteration number', 15]
# ['edges found at iteration number', 16]
# ['edges found at iteration number', 17]
# ['edges found at iteration number', 18]
# ['edges found at iteration number', 19]
# ['edges found at iteration number', 20]
# ['edges found at iteration number', 21]
# ['edges found at iteration number', 22]
# ['Starting SMP phase at', 21]
# ['entering SMP2 at iteration'] 22
# ['entering SMP2 at iteration'] 23
# ['entering SMP2 at iteration'] 24
# ['entering SMP2 at iteration'] 25
# ['entering SMP2 at iteration'] 26
# ['entering SMP2 at iteration'] 27
# ['entering SMP2 at iteration'] 28
# ['entering SMP2 at iteration'] 29
# ['entering SMP2 at iteration'] 30
# ['entering SMP2 at iteration'] 31
# ['entering SMP1 at iteration'] 32
# ['entering SMP1 at iteration'] 33
# ['entering SMP2 at iteration'] 34
# ['entering SMP1 at iteration'] 35
# ['entering SMP2 at iteration'] 36
# ['entering SMP2 at iteration'] 37
# ['entering SMP1 at iteration'] 38
# ['entering SMP2 at iteration'] 39
# ['entering SMP1 at iteration'] 40
# ['entering SMP2 at iteration'] 41
# ['entering SMP2 at iteration'] 42
# ['entering SMP1 at iteration'] 46
# ['entering SMP1 at iteration'] 48
# ['entering SMP1 at iteration'] 49
# ['entering SMP1 at iteration'] 50
# ['entering SMP1 at iteration'] 51
# ['entering SMP1 at iteration'] 53
# ['entering SMP1 at iteration'] 55
# ['entering SMP1 at iteration'] 56
# ['entering SMP1 at iteration'] 57
# ['entering SMP1 at iteration'] 58
# ['entering SMP1 at iteration'] 59
# ['entering SMP1 at iteration'] 60
# ['entering SMP1 at iteration'] 61
# ['entering SMP1 at iteration'] 62
# ['entering SMP1 at iteration'] 63
# ['entering SMP1 at iteration'] 64
# ['entering SMP1 at iteration'] 65
# ['entering SMP1 at iteration'] 66
# ['entering SMP1 at iteration'] 67
# ['entering SMP1 at iteration'] 68
# ['entering SMP1 at iteration'] 69
# ['entering SMP1 at iteration'] 70
# ['entering SMP1 at iteration'] 73
# ['entering SMP1 at iteration'] 74
# ['entering SMP1 at iteration'] 75
# ['entering SMP1 at iteration'] 76
# ['entering SMP1 at iteration'] 77
# ['entering SMP1 at iteration'] 78
# ['entering SMP1 at iteration'] 79
# ['entering SMP1 at iteration'] 80
# ['entering SMP1 at iteration'] 81
# ['entering SMP1 at iteration'] 82
# ['entering SMP1 at iteration'] 83
# ['entering SMP1 at iteration'] 84
# ['entering SMP2 at iteration'] 85
# ['entering SMP2 at iteration'] 93
# ['entering SMP1 at iteration'] 94
# ['entering SMP2 at iteration'] 95
# ['entering SMP2 at iteration'] 96
# ['entering SMP1 at iteration'] 97
# ['entering SMP1 at iteration'] 98
# ['entering SMP2 at iteration'] 99
# ['entering SMP1 at iteration'] 100
# ['entering SMP2 at iteration'] 101
# ['entering SMP1 at iteration'] 102
# ['entering SMP2 at iteration'] 103
# ['entering SMP1 at iteration'] 104
# ['entering SMP2 at iteration'] 105
# ['entering SMP2 at iteration'] 106
# ['entering SMP2 at iteration'] 107
# ['entering SMP2 at iteration'] 108
# ['entering SMP2 at iteration'] 109
# ['entering SMP2 at iteration'] 110
# ['entering SMP1 at iteration'] 111
# ['entering SMP2 at iteration'] 112
# ['entering SMP2 at iteration'] 113
# ['entering SMP2 at iteration'] 114
# ['entering SMP2 at iteration'] 115
# ['entering SMP2 at iteration'] 116
# ['entering SMP2 at iteration'] 117
# ['entering SMP2 at iteration'] 118
# ['entering SMP2 at iteration'] 119
# ['entering SMP1 at iteration'] 120
# ['entering SMP1 at iteration'] 121
# ['entering SMP2 at iteration'] 122
# ['entering SMP1 at iteration'] 123
# ['entering SMP2 at iteration'] 124
# ['entering SMP1 at iteration'] 125
# ['entering SMP1 at iteration'] 126
# ['entering SMP1 at iteration'] 127
# ['entering SMP2 at iteration'] 128
# ['entering SMP2 at iteration'] 129
# ['entering SMP2 at iteration'] 130
# ['entering SMP2 at iteration'] 131
# ['entering SMP2 at iteration'] 132
# ['entering SMP1 at iteration'] 133
# ['entering SMP2 at iteration'] 134
# ['entering SMP2 at iteration'] 135
# ['entering SMP1 at iteration'] 136
# ['entering SMP2 at iteration'] 137
# ['entering SMP1 at iteration'] 138
# ['entering SMP2 at iteration'] 139
# ['entering SMP1 at iteration'] 140
# ['entering SMP2 at iteration'] 141
# ['entering SMP1 at iteration'] 142
# ['entering SMP2 at iteration'] 143
# ['entering SMP2 at iteration'] 144
# ['entering SMP2 at iteration'] 145
# ['entering SMP2 at iteration'] 146
# ['entering SMP2 at iteration'] 147
# ['entering SMP2 at iteration'] 148
# ['entering SMP2 at iteration'] 149
# ['entering SMP2 at iteration'] 150
# ['entering SMP2 at iteration'] 151
# ['entering SMP2 at iteration'] 152
# ['entering SMP2 at iteration'] 153
# ['entering SMP2 at iteration'] 154
# ['entering SMP2 at iteration'] 155
# ['entering SMP2 at iteration'] 156
# ['entering SMP2 at iteration'] 157
# ['entering SMP2 at iteration'] 158
# ['entering SMP2 at iteration'] 159
# ['entering SMP2 at iteration'] 160
# ['entering SMP2 at iteration'] 161
# ['entering SMP2 at iteration'] 162
# ['entering SMP2 at iteration'] 163
# ['entering SMP1 at iteration'] 164
# ['entering SMP1 at iteration'] 165
# ['entering SMP1 at iteration'] 166
# ['entering SMP2 at iteration'] 167
# ['entering SMP2 at iteration'] 168
# ['entering SMP2 at iteration'] 169
# ['entering SMP2 at iteration'] 170
# ['entering SMP1 at iteration'] 171
# ['entering SMP1 at iteration'] 172
# ['entering SMP1 at iteration'] 173
# ['entering SMP1 at iteration'] 174
# ['entering SMP1 at iteration'] 175
# ['entering SMP1 at iteration'] 176

# %%
# create dataframe for the results
matched_edge_df = pd.concat(matched_edge_list)
matched_point_df = pd.concat(matched_point_list)

# %%
# measure connectivity of the link 
matched_point_df[matched_point_df['method'] == 'SMP1']
# Out:
#                           geometry                   lon_lat method
# 0   POINT (516702.076 5398591.161)  POINT (9.22717 48.74012)   SMP1
# 0   POINT (516708.090 5398607.508)  POINT (9.22725 48.74026)   SMP1
# 0   POINT (516723.670 5398660.258)  POINT (9.22747 48.74074)   SMP1
# 0   POINT (516728.403 5398696.247)  POINT (9.22753 48.74106)   SMP1
# 0   POINT (516672.210 5398734.587)  POINT (9.22677 48.74141)   SMP1
# ..                             ...                       ...    ...
# 0   POINT (518782.398 5400802.655)  POINT (9.25557 48.75995)   SMP1
# 0   POINT (518782.364 5400802.628)  POINT (9.25557 48.75995)   SMP1
# 0   POINT (518782.438 5400802.687)  POINT (9.25557 48.75995)   SMP1
# 0   POINT (518782.425 5400802.676)  POINT (9.25557 48.75995)   SMP1
# 0   POINT (518782.340 5400802.610)  POINT (9.25557 48.75995)   SMP1
#
# [66 rows x 3 columns]

# %%
np.unique(matched_edge_df['method'], return_counts=True)
# Out:
# (array(['IMP', 'SMP1', 'SMP2'], dtype=object),
#  array([ 1, 63, 85], dtype=int64))

# %%
 pd.concat(matched_edge_list)
# Out:
#                                                      osmid   lanes     ref  \
# u         v         key
# 279568483 287347230 0    [152021425, 231768650, 231768651]  [2, 3]  L 1200
# 287347230 279568483 0    [152021425, 231768650, 231768651]  [2, 3]  L 1200
#                     0    [152021425, 231768650, 231768651]  [2, 3]  L 1200
#                     0    [152021425, 231768650, 231768651]  [2, 3]  L 1200
#                     0    [152021425, 231768650, 231768651]  [2, 3]  L 1200
# ...                                                    ...     ...     ...
# 373389416 373252315 0               [161583680, 243216859]  [2, 1]  L 1198
#                     0               [161583680, 243216859]  [2, 1]  L 1198
#                     0               [161583680, 243216859]  [2, 1]  L 1198
#                     0               [161583680, 243216859]  [2, 1]  L 1198
#                     0               [161583680, 243216859]  [2, 1]  L 1198
#
#                                         name    highway maxspeed  oneway  \
# u         v         key
# 279568483 287347230 0     Kirchheimer Straße  secondary       60   False
# 287347230 279568483 0     Kirchheimer Straße  secondary       60   False
#                     0     Kirchheimer Straße  secondary       60   False
#                     0     Kirchheimer Straße  secondary       60   False
#                     0     Kirchheimer Straße  secondary       60   False
# ...                                      ...        ...      ...     ...
# 373389416 373252315 0    Otto-Hirsch-Brücken  secondary       50    True
#                     0    Otto-Hirsch-Brücken  secondary       50    True
#                     0    Otto-Hirsch-Brücken  secondary       50    True
#                     0    Otto-Hirsch-Brücken  secondary       50    True
#                     0    Otto-Hirsch-Brücken  secondary       50    True
#
#                               reversed   length  \
# u         v         key
# 279568483 287347230 0    [False, True]  298.065
# 287347230 279568483 0    [False, True]  298.065
#                     0    [False, True]  298.065
#                     0    [False, True]  298.065
#                     0    [False, True]  298.065
# ...                                ...      ...
# 373389416 373252315 0            False   71.894
#                     0            False   71.894
#                     0            False   71.894
#                     0            False   71.894
#                     0            False   71.894
#
#                                                                   geometry  \
# u         v         key
# 279568483 287347230 0    LINESTRING (516968.962 5398444.913, 516867.847...
# 287347230 279568483 0    LINESTRING (516690.066 5398551.535, 516702.561...
#                     0    LINESTRING (516690.066 5398551.535, 516702.561...
#                     0    LINESTRING (516690.066 5398551.535, 516702.561...
#                     0    LINESTRING (516690.066 5398551.535, 516702.561...
# ...                                                                    ...
# 373389416 373252315 0    LINESTRING (518737.569 5400767.631, 518754.906...
#                     0    LINESTRING (518737.569 5400767.631, 518754.906...
#                     0    LINESTRING (518737.569 5400767.631, 518754.906...
#                     0    LINESTRING (518737.569 5400767.631, 518754.906...
#                     0    LINESTRING (518737.569 5400767.631, 518754.906...
#
#                          ...  \
# u         v         key  ...
# 279568483 287347230 0    ...
# 287347230 279568483 0    ...
#                     0    ...
#                     0    ...
#                     0    ...
# ...                      ...
# 373389416 373252315 0    ...
#                     0    ...
#                     0    ...
#                     0    ...
#                     0    ...
#
#                                                                    lon_lat  \
# u         v         key
# 279568483 287347230 0    LINESTRING (9.23079 48.73879, 9.22942 48.73916...
# 287347230 279568483 0    LINESTRING (9.22701 48.73976, 9.22718 48.73973...
#                     0    LINESTRING (9.22701 48.73976, 9.22718 48.73973...
#                     0    LINESTRING (9.22701 48.73976, 9.22718 48.73973...
#                     0    LINESTRING (9.22701 48.73976, 9.22718 48.73973...
# ...                                                                    ...
# 373389416 373252315 0    LINESTRING (9.25495 48.75964, 9.25519 48.75975...
#                     0    LINESTRING (9.25495 48.75964, 9.25519 48.75975...
#                     0    LINESTRING (9.25495 48.75964, 9.25519 48.75975...
#                     0    LINESTRING (9.25495 48.75964, 9.25519 48.75975...
#                     0    LINESTRING (9.25495 48.75964, 9.25519 48.75975...
#
#                                                 str_id perp_dist  \
# u         v         key
# 279568483 287347230 0    152021425,231768650,231768651  3.189324
# 287347230 279568483 0    152021425,231768650,231768651  4.379800
#                     0    152021425,231768650,231768651  4.624059
#                     0    152021425,231768650,231768651  5.113417
#                     0    152021425,231768650,231768651  4.374081
# ...                                                ...       ...
# 373389416 373252315 0              161583680,243216859  2.225704
#                     0              161583680,243216859  2.225704
#                     0              161583680,243216859  2.225704
#                     0              161583680,243216859  2.225704
#                     0              161583680,243216859  2.225704
#
#                                                               lon_lat_pair  \
# u         v         key
# 279568483 287347230 0    [(9.2307942, 48.7387923), (9.2294206, 48.73915...
# 287347230 279568483 0    [(9.2270053, 48.739759), (9.2271751, 48.739727...
#                     0    [(9.2270053, 48.739759), (9.2271751, 48.739727...
#                     0    [(9.2270053, 48.739759), (9.2271751, 48.739727...
#                     0    [(9.2270053, 48.739759), (9.2271751, 48.739727...
# ...                                                                    ...
# 373389416 373252315 0    [(9.2549544, 48.7596366), (9.2551909, 48.75975...
#                     0    [(9.2549544, 48.7596366), (9.2551909, 48.75975...
#                     0    [(9.2549544, 48.7596366), (9.2551909, 48.75975...
#                     0    [(9.2549544, 48.7596366), (9.2551909, 48.75975...
#                     0    [(9.2549544, 48.7596366), (9.2551909, 48.75975...
#
#                         edge_heading heading_error method prev_end_node  \
# u         v         key
# 279568483 287347230 0     291.095349      6.941182    IMP           NaN
# 287347230 279568483 0     111.092501    179.967623   SMP2   287347230.0
#                     0     111.092501    179.746978   SMP2   287347230.0
#                     0     111.092501    184.602685   SMP2   287347230.0
#                     0     111.092501    178.559275   SMP2   287347230.0
# ...                              ...           ...    ...           ...
# 373389416 373252315 0      52.163583    148.836417   SMP1   373389416.0
#                     0      52.163583    148.836417   SMP1   373389416.0
#                     0      52.163583    148.836417   SMP1   373389416.0
#                     0      52.163583    148.836417   SMP1   373389416.0
#                     0      52.163583    148.836417   SMP1   373389416.0
#
#                         connectivity        d_n
# u         v         key
# 279568483 287347230 0            NaN        NaN
# 287347230 279568483 0            1.0  14.509273
#                     0            1.0   4.476720
#                     0            1.0  14.396002
#                     0            1.0  61.624940
# ...                              ...        ...
# 373389416 373252315 0            1.0   0.451555
#                     0            1.0   0.451555
#                     0            1.0   0.451555
#                     0            1.0   0.451555
#                     0            1.0   0.451555
#
# [141 rows x 27 columns]

# %% [markdown]
# # Visualize Result

# %%
# %matplotlib tk
# This is how we  visualize edges and error bound 

# plotting edges and starting point together 
f, ax = plt.subplots()

# location for all point
#locs_utm.plot(ax=ax)
point_locs = gdf_utm['geometry'].to_frame()
temp = point_locs.plot(ax = ax)

# this code plot all the road system 
edges_utm.plot(ax=ax)

# matched point plot
matched_point_df.loc[matched_point_df['method'] == 'IMP'].plot(ax = ax, color = "Green")
# matched point plot
matched_point_df.loc[matched_point_df['method'] == 'SMP1'].plot(ax = ax, color = "Red")
# matched point plot
matched_point_df.loc[matched_point_df['method'] == 'SMP2'].plot(ax = ax, color = "Yellow")


# matched_edge 
matched_edge_df.loc[matched_edge_df['connectivity'] == 0 ].plot(ax = ax, color = "Orange")
matched_edge_df.plot(ax = ax, color = "Black")
# Out:
# <Axes: >

# %%
matched_point_list
# Out:
# [                         geometry                   lon_lat method
#  0  POINT (516809.007 5398510.072)  POINT (9.22862 48.73938)    IMP,
#                           geometry                   lon_lat method
#  0  POINT (516788.872 5398517.692)  POINT (9.22835 48.73945)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516786.066 5398536.915)  POINT (9.22831 48.73962)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516762.623 5398546.316)  POINT (9.22799 48.73971)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516728.869 5398559.854)  POINT (9.22753 48.73983)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516719.496 5398554.635)  POINT (9.22741 48.73979)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516707.743 5398568.273)  POINT (9.22725 48.73991)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516707.743 5398568.273)  POINT (9.22725 48.73991)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516705.888 5398568.779)  POINT (9.22722 48.73991)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516696.198 5398571.428)  POINT (9.22709 48.73994)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516698.054 5398577.659)  POINT (9.22711 48.73999)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516702.076 5398591.161)  POINT (9.22717 48.74012)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516708.090 5398607.508)  POINT (9.22725 48.74026)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516718.447 5398631.210)  POINT (9.22739 48.74047)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516723.670 5398660.258)  POINT (9.22747 48.74074)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516726.897 5398687.414)  POINT (9.22751 48.74098)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516728.403 5398696.247)  POINT (9.22753 48.74106)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516718.572 5398723.874)  POINT (9.22740 48.74131)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516697.589 5398730.015)  POINT (9.22711 48.74136)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516670.223 5398724.080)  POINT (9.22674 48.74131)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516646.432 5398729.085)  POINT (9.22642 48.74136)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516622.406 5398737.032)  POINT (9.22609 48.74143)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516631.316 5398789.874)  POINT (9.22622 48.74190)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (516647.066 5398897.646)  POINT (9.22643 48.74287)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516659.645 5398975.854)  POINT (9.22661 48.74358)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516667.081 5399015.720)  POINT (9.22671 48.74394)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516674.904 5399055.075)  POINT (9.22682 48.74429)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516684.087 5399095.471)  POINT (9.22695 48.74465)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516704.418 5399175.667)  POINT (9.22723 48.74537)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516726.623 5399253.207)  POINT (9.22753 48.74607)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516743.554 5399306.686)  POINT (9.22776 48.74655)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516762.374 5399361.743)  POINT (9.22802 48.74705)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516776.498 5399400.221)  POINT (9.22822 48.74739)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516791.527 5399439.167)  POINT (9.22842 48.74774)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516806.750 5399477.099)  POINT (9.22863 48.74808)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516823.810 5399518.086)  POINT (9.22886 48.74845)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516840.924 5399556.748)  POINT (9.22910 48.74880)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516858.864 5399594.738)  POINT (9.22934 48.74914)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516876.994 5399632.203)  POINT (9.22959 48.74948)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516895.822 5399670.070)  POINT (9.22985 48.74982)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516915.522 5399708.269)  POINT (9.23012 48.75016)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516936.487 5399745.998)  POINT (9.23041 48.75050)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516958.675 5399784.219)  POINT (9.23071 48.75084)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (516979.481 5399819.640)  POINT (9.23099 48.75116)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517000.182 5399854.694)  POINT (9.23128 48.75147)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517020.813 5399889.673)  POINT (9.23156 48.75179)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517062.616 5399958.620)  POINT (9.23213 48.75241)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517085.412 5399992.178)  POINT (9.23244 48.75271)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517111.477 5400025.632)  POINT (9.23280 48.75301)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517143.427 5400060.126)  POINT (9.23323 48.75332)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517174.972 5400088.510)  POINT (9.23366 48.75357)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517210.879 5400113.742)  POINT (9.23415 48.75380)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517250.519 5400133.498)  POINT (9.23469 48.75397)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517291.322 5400145.224)  POINT (9.23525 48.75408)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517331.555 5400149.167)  POINT (9.23580 48.75411)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517370.374 5400145.738)  POINT (9.23633 48.75408)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517408.292 5400133.447)  POINT (9.23684 48.75397)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517442.758 5400114.820)  POINT (9.23731 48.75380)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517474.691 5400092.780)  POINT (9.23774 48.75360)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517765.093 5400080.945)  POINT (9.24169 48.75349)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517798.161 5400093.314)  POINT (9.24214 48.75360)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517823.604 5400125.187)  POINT (9.24249 48.75388)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517855.570 5400133.394)  POINT (9.24293 48.75396)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517886.994 5400134.626)  POINT (9.24335 48.75397)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517917.619 5400131.471)  POINT (9.24377 48.75394)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517941.130 5400122.148)  POINT (9.24409 48.75385)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517963.019 5400115.478)  POINT (9.24439 48.75379)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517980.122 5400108.043)  POINT (9.24462 48.75373)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517991.662 5400113.684)  POINT (9.24478 48.75378)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517993.924 5400119.610)  POINT (9.24481 48.75383)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517993.924 5400119.610)  POINT (9.24481 48.75383)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517942.202 5400132.606)  POINT (9.24410 48.75395)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517928.978 5400167.848)  POINT (9.24393 48.75426)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517898.599 5400182.180)  POINT (9.24351 48.75439)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517866.188 5400194.433)  POINT (9.24307 48.75451)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517836.598 5400231.614)  POINT (9.24267 48.75484)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517800.252 5400226.773)  POINT (9.24218 48.75480)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517773.576 5400252.244)  POINT (9.24182 48.75503)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517749.832 5400276.849)  POINT (9.24149 48.75525)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517723.648 5400287.478)  POINT (9.24114 48.75535)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517695.824 5400284.745)  POINT (9.24076 48.75532)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517669.273 5400284.650)  POINT (9.24040 48.75532)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517648.980 5400296.876)  POINT (9.24012 48.75543)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517629.686 5400306.915)  POINT (9.23986 48.75552)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517656.864 5400339.155)  POINT (9.24023 48.75581)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517692.155 5400353.324)  POINT (9.24071 48.75594)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517725.040 5400358.267)  POINT (9.24116 48.75598)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517776.160 5400361.614)  POINT (9.24186 48.75601)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517802.332 5400361.268)  POINT (9.24221 48.75601)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517842.234 5400359.810)  POINT (9.24275 48.75599)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517881.738 5400356.219)  POINT (9.24329 48.75596)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (517921.406 5400352.097)  POINT (9.24383 48.75592)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517961.179 5400347.261)  POINT (9.24437 48.75588)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (517999.381 5400342.575)  POINT (9.24489 48.75583)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518036.854 5400338.102)  POINT (9.24540 48.75579)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518071.939 5400333.928)  POINT (9.24588 48.75575)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518106.347 5400337.889)  POINT (9.24635 48.75579)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518137.211 5400350.745)  POINT (9.24677 48.75590)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518167.893 5400344.382)  POINT (9.24718 48.75585)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518203.039 5400342.380)  POINT (9.24766 48.75583)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518236.301 5400341.216)  POINT (9.24812 48.75582)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518268.616 5400368.675)  POINT (9.24856 48.75606)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518299.504 5400376.341)  POINT (9.24898 48.75613)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518329.451 5400385.329)  POINT (9.24938 48.75621)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518357.926 5400394.893)  POINT (9.24977 48.75629)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518383.896 5400407.157)  POINT (9.25013 48.75640)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518391.522 5400412.294)  POINT (9.25023 48.75645)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518408.139 5400424.827)  POINT (9.25046 48.75656)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518436.232 5400453.678)  POINT (9.25084 48.75682)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518446.864 5400466.586)  POINT (9.25099 48.75694)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518453.782 5400476.056)  POINT (9.25108 48.75702)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518469.687 5400478.521)  POINT (9.25130 48.75704)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518494.367 5400501.260)  POINT (9.25163 48.75725)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518514.331 5400514.069)  POINT (9.25191 48.75736)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518537.124 5400524.541)  POINT (9.25222 48.75746)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518562.132 5400537.205)  POINT (9.25256 48.75757)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518586.603 5400549.449)  POINT (9.25289 48.75768)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518609.891 5400563.183)  POINT (9.25321 48.75780)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518631.366 5400579.409)  POINT (9.25350 48.75795)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518662.083 5400608.684)  POINT (9.25392 48.75821)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518669.159 5400617.134)  POINT (9.25402 48.75828)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518678.400 5400639.341)  POINT (9.25414 48.75848)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518676.842 5400668.042)  POINT (9.25412 48.75874)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518686.816 5400710.029)  POINT (9.25426 48.75912)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518687.111 5400719.927)  POINT (9.25427 48.75921)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518703.032 5400742.008)  POINT (9.25448 48.75941)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518722.481 5400757.180)  POINT (9.25475 48.75954)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518737.569 5400767.631)  POINT (9.25495 48.75964)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518759.271 5400784.313)  POINT (9.25525 48.75979)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518773.654 5400795.791)  POINT (9.25545 48.75989)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518783.394 5400803.437)  POINT (9.25558 48.75996)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518787.199 5400806.425)  POINT (9.25563 48.75998)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518787.967 5400807.027)  POINT (9.25564 48.75999)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518785.895 5400805.400)  POINT (9.25561 48.75997)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518784.023 5400803.931)  POINT (9.25559 48.75996)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518782.788 5400802.961)  POINT (9.25557 48.75995)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518782.351 5400802.619)  POINT (9.25557 48.75995)   SMP2,
#                           geometry                   lon_lat method
#  0  POINT (518782.256 5400802.544)  POINT (9.25556 48.75995)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518782.398 5400802.655)  POINT (9.25557 48.75995)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518782.364 5400802.628)  POINT (9.25557 48.75995)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518782.438 5400802.687)  POINT (9.25557 48.75995)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518782.425 5400802.676)  POINT (9.25557 48.75995)   SMP1,
#                           geometry                   lon_lat method
#  0  POINT (518782.340 5400802.610)  POINT (9.25557 48.75995)   SMP1]
