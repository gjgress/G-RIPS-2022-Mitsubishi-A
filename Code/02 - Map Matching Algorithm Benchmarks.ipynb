# %% [markdown]
# # Map Matching Benchmarks
#
# This notebook is intended as a supplement to the Sendai Map notebook. This notebook implements the competing map matching algorithms and tests them against the map-matching-dataset for comparison.

# %%
import networkx as nx
import osmnx as ox 
import time
from shapely.geometry import Polygon
import os
import ujson as json
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from algorithms import mm_utils
import dask

# Remove this when debugging
#import warnings
#warnings.filterwarnings('ignore')

import dask.bag as db

# %matplotlib inline
#ox.__version__
# Out:
# /home/gjgress/.local/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
# Data Input

df_track = db.read_text('map-matching-dataset/*track.geojson').map(json.loads).map(gpd.GeoDataFrame.from_features)
df_network_edges = db.read_text('map-matching-dataset/*arcs.geojson').map(json.loads).map(gpd.GeoDataFrame.from_features)
df_network_nodes = db.read_text('map-matching-dataset/*nodes.geojson').map(json.loads).map(gpd.GeoDataFrame.from_features)
df_gt = db.read_text('map-matching-dataset/*route.geojson').map(json.loads).map(gpd.GeoDataFrame.from_features)

# %% [markdown]
# In our case, our data is already fused. But often you will have several datasets with asynchronous data that you will have to fuse first. We implemented a barebones method in mm_utils to handle this; you can see an example of how to use it in '02a Data Pre-Processing'.

# %% [markdown]
# Typically GPS/IMU data is recorded as Point geometries in a GDF.
# However, some algorithms require a trajectory (LineStrings) despite this.
# As a result, our framework requires both points (nodes) and trajectories (edges).
# So we will need to create a "trajectory" by sequentially connecting our nodes

# %%
# I wrote a utility function to do that, provided in mm_utils.

df_track_edges = df_track.map(mm_utils.point_to_traj)#, columns = {'timestamp':'first',
                                                     #  'altitude':'average',
                                                     #  'speed':'average',
                                                     #  'vertical accuracy':'last',
                                                     #  'horizontal accuracy':'last',
                                                     #  'oops':'notavalidmethod'})

# %% [markdown]
# There may be other data assigned to the nodes which we would like the edges to also reflect.
# Some algorithms may use the auxiliary data from edges, which is why this is a concern.
# There's no perfect way to do this assignment, but I included a few basic methods in mm_utils: 'first' node assignment, 'average' between nodes, and 'last' node assignment. That is the columns argument I used above.

# %%
## Network data

# Unfortunately, BDD100K does not provide network data, so we will have to pull our own from OSM
# This is computationally intense, and since we have >50000 tracks, we can't do it all at once
# So instead we will define a function to do this, and create a Dask Bag by mapping it onto our dataset
# Then it will be lazily computed
# This does mean that running our algorithm will take significantly longer
# The obvious way to circumvent this is to download all the networks beforehand
# If you do this, you may wish to create an UBODT from the networks as well (a preprocessing step done by FMM)

#def bdd_to_network(df):
#    miny, minx, maxy, maxx = df.geometry.total_bounds
#    network = ox.graph_from_bbox(maxx+0.002, minx-0.002, maxy+0.002, miny-0.002, network_type="drive")
#    networknodes, networkedges = ox.graph_to_gdfs(network)
#    return [networknodes, networkedges]

#dfbag_network = dfbag.map(bdd_to_network)

# %% [markdown]
# Now we demonstrate how we can work with several algorithms at once in a modular fashion.
#
# First we initialize the simulators, to be later applied.

# %%
from algorithms import fmm_bin
from fmm import FastMapMatchConfig

### Define map matching configurations

k = 8
radius = 0.003
gps_error = 0.0005

fmm_config = FastMapMatchConfig(k,radius,gps_error)
cfg_file = None


### Algorithm Implementation here, if not in separate .py file


###

sim1 = fmm_bin.FMM(cfg = fmm_config)
#sim2 = EKF.Sim(cfg = cfg_file)


## If you have the ground truth, load it here
ground_truth = db.read_text('map-matching-dataset/*route.geojson').map(json.loads).map(gpd.GeoDataFrame.from_features)

# %%
## We will convert our Dask Bags to Dask Delayed objects so we can iterate over them. Then we will lazily call our function on our dataset
# Finally we will compute our results, and Dask will automatically parallelize our work.

gt = ground_truth.to_delayed()
te = df_track_edges.to_delayed()
tn = df_track.to_delayed()
ne = df_network_edges.to_delayed()
nn = df_network_nodes.to_delayed()

# %% [markdown]
# Now we are ready to run the simulator on a subsection (or all of) the data. Notice how easy it is to run algorithms in parallel-- all of the parallelization is handled by Dask Delayed, so even though our algorithm is only designed to handle one case at a time, it has already gained magnitudes of efficiency.
#
# One small caveat-- even if your algorithm is technically 'independent', if you utilize python.os functions, you may run into I/O read/write errors. To circumvent this, use a dedicated library such as tempfile to systematically handle the temp file creation.

# %%
## Let's see this!
sim1_results = []

n = 50

for i in range(n):
    sim1_results.append(dask.delayed(sim1.run)(te[i],
                                               tn[i],
                                               ne[i],
                                               nn[i],
                                               return_results=True))
    
from dask.distributed import Client, LocalCluster



cluster = LocalCluster()  # Launches a scheduler and workers locally
client = Client(cluster)  # Connect to distributed cluster and override default
client.restart()
# This is the best scheduler to use when doing I/O operations (which FMM requires)

    
sim1_results[:3]
sim1_results = dask.compute(*sim1_results, scheduler='sync')

#sim1.run(input_nodes = df_nodes, input_edges = df_edges, network_nodes = networknodes, network_edges = networkedges) # FMM doesn't consider input nodes or network nodes, so the inclusion here is superfluous
#sim1.results
#sim1_results
# Out:
# 2022-07-15 01:42:37,074 - distributed.diskutils - INFO - Found stale lock file and directory '/home/gjgress/G-RIPS-2022-Mitsubishi-A/Code/dask-worker-space/worker-o9ywm2ck', purging
# 2022-07-15 01:42:37,075 - distributed.diskutils - INFO - Found stale lock file and directory '/home/gjgress/G-RIPS-2022-Mitsubishi-A/Code/dask-worker-space/worker-v4hp2mb3', purging
# 2022-07-15 01:42:37,075 - distributed.diskutils - INFO - Found stale lock file and directory '/home/gjgress/G-RIPS-2022-Mitsubishi-A/Code/dask-worker-space/worker-v_6aowuy', purging
# 2022-07-15 01:42:37,076 - distributed.diskutils - INFO - Found stale lock file and directory '/home/gjgress/G-RIPS-2022-Mitsubishi-A/Code/dask-worker-space/worker-sm1n1aif', purging
# 2022-07-15 01:42:37,599 - distributed.nanny - WARNING - Restarting worker
# 2022-07-15 01:42:37,614 - distributed.nanny - WARNING - Restarting worker
# 2022-07-15 01:42:37,618 - distributed.nanny - WARNING - Restarting worker
# 2022-07-15 01:42:37,621 - distributed.nanny - WARNING - Restarting worker
# <Client: 'tcp://127.0.0.1:43245' processes=4 threads=12, memory=14.86 GiB>
# [Delayed('run-6c9bac6f-c58e-4fab-85b2-5496340dca24'),
#  Delayed('run-a279f482-94c4-4b30-9b6f-efd5392ed870'),
#  Delayed('run-4d853809-e2ab-4918-a292-b2a75668af2c')]
# /home/gjgress/.local/lib/python3.10/site-packages/dask/base.py:1353: UserWarning: Running on a single-machine scheduler when a distributed client is active might lead to unexpected results.
#   warnings.warn(
# [2022-07-15 01:42:41.832] [info] [network.cpp:72] Read network from file /tmp/tmp8swxx8je.shp
# [2022-07-15 01:42:41.832] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:42:41.850] [info] [network.cpp:170] Number of edges 18196 nodes 8542
# [2022-07-15 01:42:41.850] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:42:41.858] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:42:42.616] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:42:42.617] [info] [network_graph.cpp:30] Graph nodes 8542 edges 18196
# [2022-07-15 01:42:42.617] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:42:42.618] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:42:42.618] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:42:42.745] [info] [ubodt_gen_algorithm.cpp:105] Progress 854 / 8542
# [2022-07-15 01:42:42.881] [info] [ubodt_gen_algorithm.cpp:105] Progress 1708 / 8542
# [2022-07-15 01:42:42.997] [info] [ubodt_gen_algorithm.cpp:105] Progress 2562 / 8542
# [2022-07-15 01:42:43.109] [info] [ubodt_gen_algorithm.cpp:105] Progress 3416 / 8542
# [2022-07-15 01:42:43.209] [info] [ubodt_gen_algorithm.cpp:105] Progress 4270 / 8542
# [2022-07-15 01:42:43.266] [info] [ubodt_gen_algorithm.cpp:105] Progress 5124 / 8542
# [2022-07-15 01:42:43.345] [info] [ubodt_gen_algorithm.cpp:105] Progress 5978 / 8542
# [2022-07-15 01:42:43.443] [info] [ubodt_gen_algorithm.cpp:105] Progress 6832 / 8542
# [2022-07-15 01:42:43.556] [info] [ubodt_gen_algorithm.cpp:105] Progress 7686 / 8542
# [2022-07-15 01:42:43.705] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmp5aro_n54
# [2022-07-15 01:42:44.254] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:42:44.468] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:42:44.468] [info] [ubodt.cpp:243] Finish reading UBODT with rows 1389502
# [2022-07-15 01:42:44.472] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:42:44.472] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpadfae0g9.shp
# [2022-07-15 01:42:44.473] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:42:44.473] [info] [gps_reader.cpp:81] Total number of trajectories 2502
# [2022-07-15 01:42:44.473] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1001
# Progress 2001
# [2022-07-15 01:43:11.125] [info] [network.cpp:72] Read network from file /tmp/tmpgdb_c_n8.shp
# [2022-07-15 01:43:11.125] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:43:11.315] [info] [network.cpp:170] Number of edges 165790 nodes 88809
# [2022-07-15 01:43:11.315] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:43:11.405] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:43:17.754] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:43:17.763] [info] [network_graph.cpp:30] Graph nodes 88809 edges 165790
# [2022-07-15 01:43:17.763] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:43:17.765] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:43:17.765] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:43:25.784] [info] [ubodt_gen_algorithm.cpp:105] Progress 8880 / 88809
# [2022-07-15 01:43:33.602] [info] [ubodt_gen_algorithm.cpp:105] Progress 17760 / 88809
# [2022-07-15 01:43:43.023] [info] [ubodt_gen_algorithm.cpp:105] Progress 26640 / 88809
# [2022-07-15 01:43:52.059] [info] [ubodt_gen_algorithm.cpp:105] Progress 35520 / 88809
# [2022-07-15 01:44:01.014] [info] [ubodt_gen_algorithm.cpp:105] Progress 44400 / 88809
# [2022-07-15 01:44:09.860] [info] [ubodt_gen_algorithm.cpp:105] Progress 53280 / 88809
# [2022-07-15 01:44:18.401] [info] [ubodt_gen_algorithm.cpp:105] Progress 62160 / 88809
# [2022-07-15 01:44:28.027] [info] [ubodt_gen_algorithm.cpp:105] Progress 71040 / 88809
# [2022-07-15 01:44:37.778] [info] [ubodt_gen_algorithm.cpp:105] Progress 79920 / 88809
# [2022-07-15 01:44:47.284] [info] [ubodt_gen_algorithm.cpp:105] Progress 88800 / 88809
# [2022-07-15 01:44:47.297] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmpqklxhzmv
# [2022-07-15 01:44:47.858] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:44:48.423] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:44:48.995] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:44:49.558] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:44:50.121] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 01:44:50.682] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 01:44:51.239] [info] [ubodt.cpp:236] Read rows 7000000
# [2022-07-15 01:44:51.801] [info] [ubodt.cpp:236] Read rows 8000000
# [2022-07-15 01:44:52.370] [info] [ubodt.cpp:236] Read rows 9000000
# [2022-07-15 01:44:52.931] [info] [ubodt.cpp:236] Read rows 10000000
# [2022-07-15 01:44:53.500] [info] [ubodt.cpp:236] Read rows 11000000
# [2022-07-15 01:44:54.056] [info] [ubodt.cpp:236] Read rows 12000000
# [2022-07-15 01:44:54.619] [info] [ubodt.cpp:236] Read rows 13000000
# [2022-07-15 01:44:55.179] [info] [ubodt.cpp:236] Read rows 14000000
# [2022-07-15 01:44:55.742] [info] [ubodt.cpp:236] Read rows 15000000
# [2022-07-15 01:44:56.306] [info] [ubodt.cpp:236] Read rows 16000000
# [2022-07-15 01:44:56.875] [info] [ubodt.cpp:236] Read rows 17000000
# [2022-07-15 01:44:57.439] [info] [ubodt.cpp:236] Read rows 18000000
# [2022-07-15 01:44:58.002] [info] [ubodt.cpp:236] Read rows 19000000
# [2022-07-15 01:44:58.569] [info] [ubodt.cpp:236] Read rows 20000000
# [2022-07-15 01:44:59.127] [info] [ubodt.cpp:236] Read rows 21000000
# [2022-07-15 01:44:59.692] [info] [ubodt.cpp:236] Read rows 22000000
# [2022-07-15 01:45:00.246] [info] [ubodt.cpp:236] Read rows 23000000
# [2022-07-15 01:45:00.820] [info] [ubodt.cpp:236] Read rows 24000000
# [2022-07-15 01:45:01.383] [info] [ubodt.cpp:236] Read rows 25000000
# [2022-07-15 01:45:01.951] [info] [ubodt.cpp:236] Read rows 26000000
# [2022-07-15 01:45:02.525] [info] [ubodt.cpp:236] Read rows 27000000
# [2022-07-15 01:45:03.093] [info] [ubodt.cpp:236] Read rows 28000000
# [2022-07-15 01:45:03.659] [info] [ubodt.cpp:236] Read rows 29000000
# [2022-07-15 01:45:04.221] [info] [ubodt.cpp:236] Read rows 30000000
# [2022-07-15 01:45:04.786] [info] [ubodt.cpp:236] Read rows 31000000
# [2022-07-15 01:45:05.350] [info] [ubodt.cpp:236] Read rows 32000000
# [2022-07-15 01:45:05.916] [info] [ubodt.cpp:236] Read rows 33000000
# [2022-07-15 01:45:06.485] [info] [ubodt.cpp:236] Read rows 34000000
# [2022-07-15 01:45:07.049] [info] [ubodt.cpp:236] Read rows 35000000
# [2022-07-15 01:45:07.613] [info] [ubodt.cpp:236] Read rows 36000000
# [2022-07-15 01:45:08.176] [info] [ubodt.cpp:236] Read rows 37000000
# [2022-07-15 01:45:08.736] [info] [ubodt.cpp:236] Read rows 38000000
# [2022-07-15 01:45:09.293] [info] [ubodt.cpp:236] Read rows 39000000
# [2022-07-15 01:45:09.853] [info] [ubodt.cpp:236] Read rows 40000000
# [2022-07-15 01:45:10.409] [info] [ubodt.cpp:236] Read rows 41000000
# [2022-07-15 01:45:10.975] [info] [ubodt.cpp:236] Read rows 42000000
# [2022-07-15 01:45:11.538] [info] [ubodt.cpp:236] Read rows 43000000
# [2022-07-15 01:45:12.098] [info] [ubodt.cpp:236] Read rows 44000000
# [2022-07-15 01:45:12.664] [info] [ubodt.cpp:236] Read rows 45000000
# [2022-07-15 01:45:13.221] [info] [ubodt.cpp:236] Read rows 46000000
# [2022-07-15 01:45:13.787] [info] [ubodt.cpp:236] Read rows 47000000
# [2022-07-15 01:45:14.345] [info] [ubodt.cpp:236] Read rows 48000000
# [2022-07-15 01:45:14.911] [info] [ubodt.cpp:236] Read rows 49000000
# [2022-07-15 01:45:15.482] [info] [ubodt.cpp:236] Read rows 50000000
# [2022-07-15 01:45:16.050] [info] [ubodt.cpp:236] Read rows 51000000
# [2022-07-15 01:45:16.618] [info] [ubodt.cpp:236] Read rows 52000000
# [2022-07-15 01:45:17.193] [info] [ubodt.cpp:236] Read rows 53000000
# [2022-07-15 01:45:17.765] [info] [ubodt.cpp:236] Read rows 54000000
# [2022-07-15 01:45:18.336] [info] [ubodt.cpp:236] Read rows 55000000
# [2022-07-15 01:45:18.905] [info] [ubodt.cpp:236] Read rows 56000000
# [2022-07-15 01:45:19.467] [info] [ubodt.cpp:236] Read rows 57000000
# [2022-07-15 01:45:20.033] [info] [ubodt.cpp:236] Read rows 58000000
# [2022-07-15 01:45:20.609] [info] [ubodt.cpp:236] Read rows 59000000
# [2022-07-15 01:45:21.180] [info] [ubodt.cpp:236] Read rows 60000000
# [2022-07-15 01:45:21.751] [info] [ubodt.cpp:236] Read rows 61000000
# [2022-07-15 01:45:22.318] [info] [ubodt.cpp:236] Read rows 62000000
# [2022-07-15 01:45:22.885] [info] [ubodt.cpp:236] Read rows 63000000
# [2022-07-15 01:45:23.445] [info] [ubodt.cpp:236] Read rows 64000000
# [2022-07-15 01:45:24.015] [info] [ubodt.cpp:236] Read rows 65000000
# [2022-07-15 01:45:24.589] [info] [ubodt.cpp:236] Read rows 66000000
# [2022-07-15 01:45:25.151] [info] [ubodt.cpp:236] Read rows 67000000
# [2022-07-15 01:45:25.716] [info] [ubodt.cpp:236] Read rows 68000000
# [2022-07-15 01:45:26.288] [info] [ubodt.cpp:236] Read rows 69000000
# [2022-07-15 01:45:26.860] [info] [ubodt.cpp:236] Read rows 70000000
# [2022-07-15 01:45:27.423] [info] [ubodt.cpp:236] Read rows 71000000
# [2022-07-15 01:45:27.989] [info] [ubodt.cpp:236] Read rows 72000000
# [2022-07-15 01:45:28.555] [info] [ubodt.cpp:236] Read rows 73000000
# [2022-07-15 01:45:29.118] [info] [ubodt.cpp:236] Read rows 74000000
# [2022-07-15 01:45:29.690] [info] [ubodt.cpp:236] Read rows 75000000
# [2022-07-15 01:45:30.258] [info] [ubodt.cpp:236] Read rows 76000000
# [2022-07-15 01:45:30.827] [info] [ubodt.cpp:236] Read rows 77000000
# [2022-07-15 01:45:31.397] [info] [ubodt.cpp:236] Read rows 78000000
# [2022-07-15 01:45:31.967] [info] [ubodt.cpp:236] Read rows 79000000
# [2022-07-15 01:45:32.534] [info] [ubodt.cpp:236] Read rows 80000000
# [2022-07-15 01:45:33.099] [info] [ubodt.cpp:236] Read rows 81000000
# [2022-07-15 01:45:33.669] [info] [ubodt.cpp:236] Read rows 82000000
# [2022-07-15 01:45:34.236] [info] [ubodt.cpp:236] Read rows 83000000
# [2022-07-15 01:45:34.802] [info] [ubodt.cpp:236] Read rows 84000000
# [2022-07-15 01:45:35.364] [info] [ubodt.cpp:236] Read rows 85000000
# [2022-07-15 01:45:35.927] [info] [ubodt.cpp:236] Read rows 86000000
# [2022-07-15 01:45:36.501] [info] [ubodt.cpp:236] Read rows 87000000
# [2022-07-15 01:45:37.059] [info] [ubodt.cpp:236] Read rows 88000000
# [2022-07-15 01:45:37.632] [info] [ubodt.cpp:236] Read rows 89000000
# [2022-07-15 01:45:38.191] [info] [ubodt.cpp:236] Read rows 90000000
# [2022-07-15 01:45:38.758] [info] [ubodt.cpp:236] Read rows 91000000
# [2022-07-15 01:45:39.325] [info] [ubodt.cpp:236] Read rows 92000000
# [2022-07-15 01:45:39.892] [info] [ubodt.cpp:236] Read rows 93000000
# [2022-07-15 01:45:40.456] [info] [ubodt.cpp:236] Read rows 94000000
# [2022-07-15 01:45:41.023] [info] [ubodt.cpp:236] Read rows 95000000
# [2022-07-15 01:45:41.590] [info] [ubodt.cpp:236] Read rows 96000000
# [2022-07-15 01:45:42.157] [info] [ubodt.cpp:236] Read rows 97000000
# [2022-07-15 01:45:42.724] [info] [ubodt.cpp:236] Read rows 98000000
# [2022-07-15 01:45:43.291] [info] [ubodt.cpp:236] Read rows 99000000
# [2022-07-15 01:45:43.864] [info] [ubodt.cpp:236] Read rows 100000000
# [2022-07-15 01:45:44.432] [info] [ubodt.cpp:236] Read rows 101000000
# [2022-07-15 01:45:45.008] [info] [ubodt.cpp:236] Read rows 102000000
# [2022-07-15 01:45:45.578] [info] [ubodt.cpp:236] Read rows 103000000
# [2022-07-15 01:45:46.146] [info] [ubodt.cpp:236] Read rows 104000000
# [2022-07-15 01:45:46.718] [info] [ubodt.cpp:236] Read rows 105000000
# [2022-07-15 01:45:46.777] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:45:46.777] [info] [ubodt.cpp:243] Finish reading UBODT with rows 105105818
# [2022-07-15 01:45:47.035] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:45:47.035] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpsbp9y0_r.shp
# [2022-07-15 01:45:47.035] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:45:47.035] [info] [gps_reader.cpp:81] Total number of trajectories 1314
# [2022-07-15 01:45:47.035] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# [2022-07-15 01:46:57.583] [info] [network.cpp:72] Read network from file /tmp/tmpvgn5um4q.shp
# [2022-07-15 01:46:57.583] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:46:57.603] [info] [network.cpp:170] Number of edges 16139 nodes 7936
# [2022-07-15 01:46:57.603] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:46:57.610] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:46:58.200] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:46:58.201] [info] [network_graph.cpp:30] Graph nodes 7936 edges 16139
# [2022-07-15 01:46:58.201] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:46:58.202] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:46:58.202] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:46:58.797] [info] [ubodt_gen_algorithm.cpp:105] Progress 793 / 7936
# [2022-07-15 01:46:59.426] [info] [ubodt_gen_algorithm.cpp:105] Progress 1586 / 7936
# [2022-07-15 01:47:00.028] [info] [ubodt_gen_algorithm.cpp:105] Progress 2379 / 7936
# [2022-07-15 01:47:00.730] [info] [ubodt_gen_algorithm.cpp:105] Progress 3172 / 7936
# [2022-07-15 01:47:01.447] [info] [ubodt_gen_algorithm.cpp:105] Progress 3965 / 7936
# [2022-07-15 01:47:02.244] [info] [ubodt_gen_algorithm.cpp:105] Progress 4758 / 7936
# [2022-07-15 01:47:03.053] [info] [ubodt_gen_algorithm.cpp:105] Progress 5551 / 7936
# [2022-07-15 01:47:03.947] [info] [ubodt_gen_algorithm.cpp:105] Progress 6344 / 7936
# [2022-07-15 01:47:04.719] [info] [ubodt_gen_algorithm.cpp:105] Progress 7137 / 7936
# [2022-07-15 01:47:05.599] [info] [ubodt_gen_algorithm.cpp:105] Progress 7930 / 7936
# [2022-07-15 01:47:05.608] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmprps963fa
# [2022-07-15 01:47:06.131] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:47:06.655] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:47:07.178] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:47:07.700] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:47:08.225] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 01:47:08.752] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 01:47:09.275] [info] [ubodt.cpp:236] Read rows 7000000
# [2022-07-15 01:47:09.798] [info] [ubodt.cpp:236] Read rows 8000000
# [2022-07-15 01:47:10.321] [info] [ubodt.cpp:236] Read rows 9000000
# [2022-07-15 01:47:10.466] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:47:10.466] [info] [ubodt.cpp:243] Finish reading UBODT with rows 9278637
# [2022-07-15 01:47:10.491] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:47:10.491] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpnh404oxn.shp
# [2022-07-15 01:47:10.492] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:47:10.492] [info] [gps_reader.cpp:81] Total number of trajectories 7242
# [2022-07-15 01:47:10.492] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# Progress 2000
# Progress 3000
# Progress 4000
# Progress 5000
# Progress 6000
# Progress 7000
# [2022-07-15 01:47:20.680] [info] [network.cpp:72] Read network from file /tmp/tmph19lx0s6.shp
# [2022-07-15 01:47:20.680] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:47:20.700] [info] [network.cpp:170] Number of edges 18028 nodes 9138
# [2022-07-15 01:47:20.700] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:47:20.709] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:47:21.474] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:47:21.475] [info] [network_graph.cpp:30] Graph nodes 9138 edges 18028
# [2022-07-15 01:47:21.475] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:47:21.475] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:47:21.475] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:47:22.133] [info] [ubodt_gen_algorithm.cpp:105] Progress 913 / 9138
# [2022-07-15 01:47:22.831] [info] [ubodt_gen_algorithm.cpp:105] Progress 1826 / 9138
# [2022-07-15 01:47:23.481] [info] [ubodt_gen_algorithm.cpp:105] Progress 2739 / 9138
# [2022-07-15 01:47:24.233] [info] [ubodt_gen_algorithm.cpp:105] Progress 3652 / 9138
# [2022-07-15 01:47:24.949] [info] [ubodt_gen_algorithm.cpp:105] Progress 4565 / 9138
# [2022-07-15 01:47:25.627] [info] [ubodt_gen_algorithm.cpp:105] Progress 5478 / 9138
# [2022-07-15 01:47:26.473] [info] [ubodt_gen_algorithm.cpp:105] Progress 6391 / 9138
# [2022-07-15 01:47:27.279] [info] [ubodt_gen_algorithm.cpp:105] Progress 7304 / 9138
# [2022-07-15 01:47:28.054] [info] [ubodt_gen_algorithm.cpp:105] Progress 8217 / 9138
# [2022-07-15 01:47:28.742] [info] [ubodt_gen_algorithm.cpp:105] Progress 9130 / 9138
# [2022-07-15 01:47:28.758] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmp38nh1czu
# [2022-07-15 01:47:29.286] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:47:29.811] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:47:30.332] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:47:30.859] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:47:31.382] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 01:47:31.908] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 01:47:32.433] [info] [ubodt.cpp:236] Read rows 7000000
# [2022-07-15 01:47:32.955] [info] [ubodt.cpp:236] Read rows 8000000
# [2022-07-15 01:47:33.480] [info] [ubodt.cpp:236] Read rows 9000000
# [2022-07-15 01:47:33.579] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:47:33.579] [info] [ubodt.cpp:243] Finish reading UBODT with rows 9188235
# [2022-07-15 01:47:33.603] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:47:33.603] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpyn37f6c9.shp
# [2022-07-15 01:47:33.604] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:47:33.604] [info] [gps_reader.cpp:81] Total number of trajectories 820
# [2022-07-15 01:47:33.604] [info] [gps_reader.cpp:82] Finish reading meta data
# [2022-07-15 01:47:39.563] [info] [network.cpp:72] Read network from file /tmp/tmpywnnj2ud.shp
# [2022-07-15 01:47:39.563] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:47:39.581] [info] [network.cpp:170] Number of edges 15499 nodes 7350
# [2022-07-15 01:47:39.581] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:47:39.588] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:47:40.140] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:47:40.141] [info] [network_graph.cpp:30] Graph nodes 7350 edges 15499
# [2022-07-15 01:47:40.141] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:47:40.141] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:47:40.141] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:47:40.308] [info] [ubodt_gen_algorithm.cpp:105] Progress 735 / 7350
# [2022-07-15 01:47:40.590] [info] [ubodt_gen_algorithm.cpp:105] Progress 1470 / 7350
# [2022-07-15 01:47:40.848] [info] [ubodt_gen_algorithm.cpp:105] Progress 2205 / 7350
# [2022-07-15 01:47:41.120] [info] [ubodt_gen_algorithm.cpp:105] Progress 2940 / 7350
# [2022-07-15 01:47:41.380] [info] [ubodt_gen_algorithm.cpp:105] Progress 3675 / 7350
# [2022-07-15 01:47:41.621] [info] [ubodt_gen_algorithm.cpp:105] Progress 4410 / 7350
# [2022-07-15 01:47:41.890] [info] [ubodt_gen_algorithm.cpp:105] Progress 5145 / 7350
# [2022-07-15 01:47:42.085] [info] [ubodt_gen_algorithm.cpp:105] Progress 5880 / 7350
# [2022-07-15 01:47:42.380] [info] [ubodt_gen_algorithm.cpp:105] Progress 6615 / 7350
# [2022-07-15 01:47:42.874] [info] [ubodt_gen_algorithm.cpp:105] Progress 7350 / 7350
# [2022-07-15 01:47:42.877] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmpnu5t72s5
# [2022-07-15 01:47:43.401] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:47:43.923] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:47:44.442] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:47:44.689] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:47:44.689] [info] [ubodt.cpp:243] Finish reading UBODT with rows 3472229
# [2022-07-15 01:47:44.700] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:47:44.700] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpduo0c6et.shp
# [2022-07-15 01:47:44.701] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:47:44.701] [info] [gps_reader.cpp:81] Total number of trajectories 1063
# [2022-07-15 01:47:44.701] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# [2022-07-15 01:47:46.319] [info] [network.cpp:72] Read network from file /tmp/tmpgqa85sj2.shp
# [2022-07-15 01:47:46.320] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:47:46.321] [info] [network.cpp:170] Number of edges 1579 nodes 898
# [2022-07-15 01:47:46.321] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:47:46.322] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:47:46.383] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:47:46.383] [info] [network_graph.cpp:30] Graph nodes 898 edges 1579
# [2022-07-15 01:47:46.383] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:47:46.383] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:47:46.383] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:47:46.387] [info] [ubodt_gen_algorithm.cpp:105] Progress 89 / 898
# [2022-07-15 01:47:46.392] [info] [ubodt_gen_algorithm.cpp:105] Progress 178 / 898
# [2022-07-15 01:47:46.396] [info] [ubodt_gen_algorithm.cpp:105] Progress 267 / 898
# [2022-07-15 01:47:46.400] [info] [ubodt_gen_algorithm.cpp:105] Progress 356 / 898
# [2022-07-15 01:47:46.402] [info] [ubodt_gen_algorithm.cpp:105] Progress 445 / 898
# [2022-07-15 01:47:46.405] [info] [ubodt_gen_algorithm.cpp:105] Progress 534 / 898
# [2022-07-15 01:47:46.409] [info] [ubodt_gen_algorithm.cpp:105] Progress 623 / 898
# [2022-07-15 01:47:46.414] [info] [ubodt_gen_algorithm.cpp:105] Progress 712 / 898
# [2022-07-15 01:47:46.417] [info] [ubodt_gen_algorithm.cpp:105] Progress 801 / 898
# [2022-07-15 01:47:46.421] [info] [ubodt_gen_algorithm.cpp:105] Progress 890 / 898
# [2022-07-15 01:47:46.425] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmpgmxpshz7
# [2022-07-15 01:47:46.451] [info] [ubodt.cpp:243] Finish reading UBODT with rows 48267
# [2022-07-15 01:47:46.451] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:47:46.451] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmprm5gzlp7.shp
# [2022-07-15 01:47:46.452] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:47:46.452] [info] [gps_reader.cpp:81] Total number of trajectories 1044
# [2022-07-15 01:47:46.452] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# [2022-07-15 01:47:47.909] [info] [network.cpp:72] Read network from file /tmp/tmpl_hhiamu.shp
# [2022-07-15 01:47:47.909] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:47:47.916] [info] [network.cpp:170] Number of edges 6757 nodes 3259
# [2022-07-15 01:47:47.916] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:47:47.919] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:47:48.164] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:47:48.164] [info] [network_graph.cpp:30] Graph nodes 3259 edges 6757
# [2022-07-15 01:47:48.164] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:47:48.164] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:47:48.164] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:47:48.248] [info] [ubodt_gen_algorithm.cpp:105] Progress 325 / 3259
# [2022-07-15 01:47:48.326] [info] [ubodt_gen_algorithm.cpp:105] Progress 650 / 3259
# [2022-07-15 01:47:48.407] [info] [ubodt_gen_algorithm.cpp:105] Progress 975 / 3259
# [2022-07-15 01:47:48.479] [info] [ubodt_gen_algorithm.cpp:105] Progress 1300 / 3259
# [2022-07-15 01:47:48.565] [info] [ubodt_gen_algorithm.cpp:105] Progress 1625 / 3259
# [2022-07-15 01:47:48.637] [info] [ubodt_gen_algorithm.cpp:105] Progress 1950 / 3259
# [2022-07-15 01:47:48.699] [info] [ubodt_gen_algorithm.cpp:105] Progress 2275 / 3259
# [2022-07-15 01:47:48.776] [info] [ubodt_gen_algorithm.cpp:105] Progress 2600 / 3259
# [2022-07-15 01:47:48.861] [info] [ubodt_gen_algorithm.cpp:105] Progress 2925 / 3259
# [2022-07-15 01:47:48.946] [info] [ubodt_gen_algorithm.cpp:105] Progress 3250 / 3259
# [2022-07-15 01:47:48.951] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmpj_xw3d28
# [2022-07-15 01:47:49.468] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:47:49.478] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:47:49.478] [info] [ubodt.cpp:243] Finish reading UBODT with rows 1019201
# [2022-07-15 01:47:49.482] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:47:49.482] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmps7eej1fp.shp
# [2022-07-15 01:47:49.482] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:47:49.482] [info] [gps_reader.cpp:81] Total number of trajectories 1449
# [2022-07-15 01:47:49.482] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# [2022-07-15 01:47:50.846] [info] [network.cpp:72] Read network from file /tmp/tmphnkntpr5.shp
# [2022-07-15 01:47:50.847] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:47:50.851] [info] [network.cpp:170] Number of edges 4369 nodes 2061
# [2022-07-15 01:47:50.851] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:47:50.853] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:47:51.014] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:47:51.014] [info] [network_graph.cpp:30] Graph nodes 2061 edges 4369
# [2022-07-15 01:47:51.014] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:47:51.014] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:47:51.014] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:47:51.092] [info] [ubodt_gen_algorithm.cpp:105] Progress 206 / 2061
# [2022-07-15 01:47:51.146] [info] [ubodt_gen_algorithm.cpp:105] Progress 412 / 2061
# [2022-07-15 01:47:51.218] [info] [ubodt_gen_algorithm.cpp:105] Progress 618 / 2061
# [2022-07-15 01:47:51.287] [info] [ubodt_gen_algorithm.cpp:105] Progress 824 / 2061
# [2022-07-15 01:47:51.334] [info] [ubodt_gen_algorithm.cpp:105] Progress 1030 / 2061
# [2022-07-15 01:47:51.378] [info] [ubodt_gen_algorithm.cpp:105] Progress 1236 / 2061
# [2022-07-15 01:47:51.442] [info] [ubodt_gen_algorithm.cpp:105] Progress 1442 / 2061
# [2022-07-15 01:47:51.483] [info] [ubodt_gen_algorithm.cpp:105] Progress 1648 / 2061
# [2022-07-15 01:47:51.554] [info] [ubodt_gen_algorithm.cpp:105] Progress 1854 / 2061
# [2022-07-15 01:47:51.685] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmpoa2jnd20
# [2022-07-15 01:47:52.117] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:47:52.117] [info] [ubodt.cpp:243] Finish reading UBODT with rows 839559
# [2022-07-15 01:47:52.121] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:47:52.121] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmp1onl26xl.shp
# [2022-07-15 01:47:52.121] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:47:52.121] [info] [gps_reader.cpp:81] Total number of trajectories 1353
# [2022-07-15 01:47:52.121] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1001
# [2022-07-15 01:47:54.526] [info] [network.cpp:72] Read network from file /tmp/tmpyxrlqfb7.shp
# [2022-07-15 01:47:54.526] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:47:54.538] [info] [network.cpp:170] Number of edges 10421 nodes 4995
# [2022-07-15 01:47:54.538] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:47:54.543] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:47:55.012] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:47:55.012] [info] [network_graph.cpp:30] Graph nodes 4995 edges 10421
# [2022-07-15 01:47:55.012] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:47:55.012] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:47:55.012] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:47:55.581] [info] [ubodt_gen_algorithm.cpp:105] Progress 499 / 4995
# [2022-07-15 01:47:56.100] [info] [ubodt_gen_algorithm.cpp:105] Progress 998 / 4995
# [2022-07-15 01:47:56.691] [info] [ubodt_gen_algorithm.cpp:105] Progress 1497 / 4995
# [2022-07-15 01:47:57.208] [info] [ubodt_gen_algorithm.cpp:105] Progress 1996 / 4995
# [2022-07-15 01:47:57.734] [info] [ubodt_gen_algorithm.cpp:105] Progress 2495 / 4995
# [2022-07-15 01:47:58.271] [info] [ubodt_gen_algorithm.cpp:105] Progress 2994 / 4995
# [2022-07-15 01:47:58.806] [info] [ubodt_gen_algorithm.cpp:105] Progress 3493 / 4995
# [2022-07-15 01:47:59.375] [info] [ubodt_gen_algorithm.cpp:105] Progress 3992 / 4995
# [2022-07-15 01:47:59.961] [info] [ubodt_gen_algorithm.cpp:105] Progress 4491 / 4995
# [2022-07-15 01:48:00.585] [info] [ubodt_gen_algorithm.cpp:105] Progress 4990 / 4995
# [2022-07-15 01:48:00.594] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmp1tql13nv
# [2022-07-15 01:48:01.117] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:48:01.638] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:48:02.161] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:48:02.682] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:48:03.204] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 01:48:03.729] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 01:48:04.248] [info] [ubodt.cpp:236] Read rows 7000000
# [2022-07-15 01:48:04.277] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:48:04.277] [info] [ubodt.cpp:243] Finish reading UBODT with rows 7055326
# [2022-07-15 01:48:04.294] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:48:04.294] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpff4xx3u6.shp
# [2022-07-15 01:48:04.294] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:48:04.294] [info] [gps_reader.cpp:81] Total number of trajectories 3092
# [2022-07-15 01:48:04.294] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# Progress 2000
# Progress 3000
# [2022-07-15 01:48:09.721] [info] [network.cpp:72] Read network from file /tmp/tmpllwg0nt_.shp
# [2022-07-15 01:48:09.722] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:48:09.736] [info] [network.cpp:170] Number of edges 13106 nodes 6745
# [2022-07-15 01:48:09.736] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:48:09.742] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:48:10.318] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:48:10.319] [info] [network_graph.cpp:30] Graph nodes 6745 edges 13106
# [2022-07-15 01:48:10.319] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:48:10.319] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:48:10.319] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:48:10.925] [info] [ubodt_gen_algorithm.cpp:105] Progress 674 / 6745
# [2022-07-15 01:48:11.407] [info] [ubodt_gen_algorithm.cpp:105] Progress 1348 / 6745
# [2022-07-15 01:48:11.807] [info] [ubodt_gen_algorithm.cpp:105] Progress 2022 / 6745
# [2022-07-15 01:48:12.357] [info] [ubodt_gen_algorithm.cpp:105] Progress 2696 / 6745
# [2022-07-15 01:48:12.977] [info] [ubodt_gen_algorithm.cpp:105] Progress 3370 / 6745
# [2022-07-15 01:48:13.511] [info] [ubodt_gen_algorithm.cpp:105] Progress 4044 / 6745
# [2022-07-15 01:48:13.999] [info] [ubodt_gen_algorithm.cpp:105] Progress 4718 / 6745
# [2022-07-15 01:48:14.480] [info] [ubodt_gen_algorithm.cpp:105] Progress 5392 / 6745
# [2022-07-15 01:48:15.003] [info] [ubodt_gen_algorithm.cpp:105] Progress 6066 / 6745
# [2022-07-15 01:48:15.668] [info] [ubodt_gen_algorithm.cpp:105] Progress 6740 / 6745
# [2022-07-15 01:48:15.686] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmp5ldhlikf
# [2022-07-15 01:48:16.211] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:48:16.745] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:48:17.272] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:48:17.801] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:48:18.327] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 01:48:18.853] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 01:48:19.270] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:48:19.270] [info] [ubodt.cpp:243] Finish reading UBODT with rows 6790751
# [2022-07-15 01:48:19.288] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:48:19.288] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmps3vpj4_a.shp
# [2022-07-15 01:48:19.289] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:48:19.289] [info] [gps_reader.cpp:81] Total number of trajectories 1048
# [2022-07-15 01:48:19.289] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# [2022-07-15 01:48:24.736] [info] [network.cpp:72] Read network from file /tmp/tmpfdfmpgs2.shp
# [2022-07-15 01:48:24.736] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:48:24.754] [info] [network.cpp:170] Number of edges 15715 nodes 8502
# [2022-07-15 01:48:24.754] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:48:24.761] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:48:25.322] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:48:25.323] [info] [network_graph.cpp:30] Graph nodes 8502 edges 15715
# [2022-07-15 01:48:25.323] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:48:25.323] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:48:25.323] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:48:25.735] [info] [ubodt_gen_algorithm.cpp:105] Progress 850 / 8502
# [2022-07-15 01:48:26.091] [info] [ubodt_gen_algorithm.cpp:105] Progress 1700 / 8502
# [2022-07-15 01:48:26.452] [info] [ubodt_gen_algorithm.cpp:105] Progress 2550 / 8502
# [2022-07-15 01:48:26.837] [info] [ubodt_gen_algorithm.cpp:105] Progress 3400 / 8502
# [2022-07-15 01:48:27.244] [info] [ubodt_gen_algorithm.cpp:105] Progress 4250 / 8502
# [2022-07-15 01:48:27.590] [info] [ubodt_gen_algorithm.cpp:105] Progress 5100 / 8502
# [2022-07-15 01:48:27.995] [info] [ubodt_gen_algorithm.cpp:105] Progress 5950 / 8502
# [2022-07-15 01:48:28.373] [info] [ubodt_gen_algorithm.cpp:105] Progress 6800 / 8502
# [2022-07-15 01:48:28.747] [info] [ubodt_gen_algorithm.cpp:105] Progress 7650 / 8502
# [2022-07-15 01:48:29.164] [info] [ubodt_gen_algorithm.cpp:105] Progress 8500 / 8502
# [2022-07-15 01:48:29.172] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmphu93cfl9
# [2022-07-15 01:48:29.705] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:48:30.232] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:48:30.759] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:48:31.286] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:48:31.809] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:48:31.809] [info] [ubodt.cpp:243] Finish reading UBODT with rows 4997930
# [2022-07-15 01:48:31.825] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:48:31.825] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmp3ji7zqig.shp
# [2022-07-15 01:48:31.825] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:48:31.825] [info] [gps_reader.cpp:81] Total number of trajectories 2710
# [2022-07-15 01:48:31.825] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# Progress 2000
# [2022-07-15 01:48:35.839] [info] [network.cpp:72] Read network from file /tmp/tmpsj37mec9.shp
# [2022-07-15 01:48:35.839] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:48:35.845] [info] [network.cpp:170] Number of edges 5393 nodes 2649
# [2022-07-15 01:48:35.845] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:48:35.848] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:48:36.147] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:48:36.147] [info] [network_graph.cpp:30] Graph nodes 2649 edges 5393
# [2022-07-15 01:48:36.147] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:48:36.147] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:48:36.147] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:48:36.178] [info] [ubodt_gen_algorithm.cpp:105] Progress 264 / 2649
# [2022-07-15 01:48:36.205] [info] [ubodt_gen_algorithm.cpp:105] Progress 528 / 2649
# [2022-07-15 01:48:36.236] [info] [ubodt_gen_algorithm.cpp:105] Progress 792 / 2649
# [2022-07-15 01:48:36.261] [info] [ubodt_gen_algorithm.cpp:105] Progress 1056 / 2649
# [2022-07-15 01:48:36.285] [info] [ubodt_gen_algorithm.cpp:105] Progress 1320 / 2649
# [2022-07-15 01:48:36.310] [info] [ubodt_gen_algorithm.cpp:105] Progress 1584 / 2649
# [2022-07-15 01:48:36.346] [info] [ubodt_gen_algorithm.cpp:105] Progress 1848 / 2649
# [2022-07-15 01:48:36.383] [info] [ubodt_gen_algorithm.cpp:105] Progress 2112 / 2649
# [2022-07-15 01:48:36.425] [info] [ubodt_gen_algorithm.cpp:105] Progress 2376 / 2649
# [2022-07-15 01:48:36.478] [info] [ubodt_gen_algorithm.cpp:105] Progress 2640 / 2649
# [2022-07-15 01:48:36.487] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmpiplp7832
# [2022-07-15 01:48:36.721] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:48:36.721] [info] [ubodt.cpp:243] Finish reading UBODT with rows 441208
# [2022-07-15 01:48:36.723] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:48:36.723] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpyu1373_0.shp
# [2022-07-15 01:48:36.724] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:48:36.724] [info] [gps_reader.cpp:81] Total number of trajectories 2827
# [2022-07-15 01:48:36.724] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# Progress 2000
# [2022-07-15 01:48:43.156] [info] [network.cpp:72] Read network from file /tmp/tmp07sfwdg6.shp
# [2022-07-15 01:48:43.156] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:48:43.197] [info] [network.cpp:170] Number of edges 38599 nodes 16376
# [2022-07-15 01:48:43.197] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:48:43.215] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:48:44.719] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:48:44.721] [info] [network_graph.cpp:30] Graph nodes 16376 edges 38599
# [2022-07-15 01:48:44.721] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:48:44.721] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:48:44.721] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:48:45.569] [info] [ubodt_gen_algorithm.cpp:105] Progress 1637 / 16376
# [2022-07-15 01:48:46.406] [info] [ubodt_gen_algorithm.cpp:105] Progress 3274 / 16376
# [2022-07-15 01:48:47.381] [info] [ubodt_gen_algorithm.cpp:105] Progress 4911 / 16376
# [2022-07-15 01:48:48.390] [info] [ubodt_gen_algorithm.cpp:105] Progress 6548 / 16376
# [2022-07-15 01:48:49.485] [info] [ubodt_gen_algorithm.cpp:105] Progress 8185 / 16376
# [2022-07-15 01:48:50.553] [info] [ubodt_gen_algorithm.cpp:105] Progress 9822 / 16376
# [2022-07-15 01:48:51.471] [info] [ubodt_gen_algorithm.cpp:105] Progress 11459 / 16376
# [2022-07-15 01:48:52.240] [info] [ubodt_gen_algorithm.cpp:105] Progress 13096 / 16376
# [2022-07-15 01:48:53.140] [info] [ubodt_gen_algorithm.cpp:105] Progress 14733 / 16376
# [2022-07-15 01:48:54.026] [info] [ubodt_gen_algorithm.cpp:105] Progress 16370 / 16376
# [2022-07-15 01:48:54.039] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmpbip0dj25
# [2022-07-15 01:48:54.588] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:48:55.128] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:48:55.668] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:48:56.203] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:48:56.740] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 01:48:57.279] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 01:48:57.814] [info] [ubodt.cpp:236] Read rows 7000000
# [2022-07-15 01:48:58.342] [info] [ubodt.cpp:236] Read rows 8000000
# [2022-07-15 01:48:58.868] [info] [ubodt.cpp:236] Read rows 9000000
# [2022-07-15 01:48:59.398] [info] [ubodt.cpp:236] Read rows 10000000
# [2022-07-15 01:48:59.933] [info] [ubodt.cpp:236] Read rows 11000000
# [2022-07-15 01:49:00.335] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 01:49:00.335] [info] [ubodt.cpp:243] Finish reading UBODT with rows 11745897
# [2022-07-15 01:49:00.364] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 01:49:00.364] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmppt328hkh.shp
# [2022-07-15 01:49:00.365] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 01:49:00.365] [info] [gps_reader.cpp:81] Total number of trajectories 1607
# [2022-07-15 01:49:00.365] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# [2022-07-15 01:49:53.518] [info] [network.cpp:72] Read network from file /tmp/tmppzrhizg3.shp
# [2022-07-15 01:49:53.520] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 01:49:53.860] [info] [network.cpp:170] Number of edges 307392 nodes 155003
# [2022-07-15 01:49:53.860] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 01:49:54.017] [info] [network.cpp:174] Read network done.
# [2022-07-15 01:50:05.175] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 01:50:05.192] [info] [network_graph.cpp:30] Graph nodes 155003 edges 307392
# [2022-07-15 01:50:05.192] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 01:50:05.193] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 01:50:05.193] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 01:50:12.179] [info] [ubodt_gen_algorithm.cpp:105] Progress 15500 / 155003
# [2022-07-15 01:50:20.183] [info] [ubodt_gen_algorithm.cpp:105] Progress 31000 / 155003
# [2022-07-15 01:50:30.206] [info] [ubodt_gen_algorithm.cpp:105] Progress 46500 / 155003
# [2022-07-15 01:50:39.951] [info] [ubodt_gen_algorithm.cpp:105] Progress 62000 / 155003
# [2022-07-15 01:50:47.859] [info] [ubodt_gen_algorithm.cpp:105] Progress 77500 / 155003
# [2022-07-15 01:50:55.061] [info] [ubodt_gen_algorithm.cpp:105] Progress 93000 / 155003
# [2022-07-15 01:51:03.330] [info] [ubodt_gen_algorithm.cpp:105] Progress 108500 / 155003
# [2022-07-15 01:51:11.536] [info] [ubodt_gen_algorithm.cpp:105] Progress 124000 / 155003
# [2022-07-15 01:51:20.394] [info] [ubodt_gen_algorithm.cpp:105] Progress 139500 / 155003
# [2022-07-15 01:51:31.300] [info] [ubodt_gen_algorithm.cpp:105] Progress 155000 / 155003
# [2022-07-15 01:51:31.308] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmp_b1s2xwe
# [2022-07-15 01:51:31.857] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 01:51:32.404] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 01:51:32.960] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 01:51:33.515] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 01:51:34.070] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 01:51:34.618] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 01:51:35.164] [info] [ubodt.cpp:236] Read rows 7000000
# [2022-07-15 01:51:35.712] [info] [ubodt.cpp:236] Read rows 8000000
# [2022-07-15 01:51:36.262] [info] [ubodt.cpp:236] Read rows 9000000
# [2022-07-15 01:51:36.811] [info] [ubodt.cpp:236] Read rows 10000000
# [2022-07-15 01:51:37.362] [info] [ubodt.cpp:236] Read rows 11000000
# [2022-07-15 01:51:37.913] [info] [ubodt.cpp:236] Read rows 12000000
# [2022-07-15 01:51:38.460] [info] [ubodt.cpp:236] Read rows 13000000
# [2022-07-15 01:51:39.010] [info] [ubodt.cpp:236] Read rows 14000000
# [2022-07-15 01:51:39.563] [info] [ubodt.cpp:236] Read rows 15000000
# [2022-07-15 01:51:40.112] [info] [ubodt.cpp:236] Read rows 16000000
# [2022-07-15 01:51:40.665] [info] [ubodt.cpp:236] Read rows 17000000
# [2022-07-15 01:51:41.217] [info] [ubodt.cpp:236] Read rows 18000000
# [2022-07-15 01:51:41.765] [info] [ubodt.cpp:236] Read rows 19000000
# [2022-07-15 01:51:42.309] [info] [ubodt.cpp:236] Read rows 20000000
# [2022-07-15 01:51:42.855] [info] [ubodt.cpp:236] Read rows 21000000
# [2022-07-15 01:51:43.405] [info] [ubodt.cpp:236] Read rows 22000000
# [2022-07-15 01:51:43.946] [info] [ubodt.cpp:236] Read rows 23000000
# [2022-07-15 01:51:44.486] [info] [ubodt.cpp:236] Read rows 24000000
# [2022-07-15 01:51:45.036] [info] [ubodt.cpp:236] Read rows 25000000
# [2022-07-15 01:51:45.581] [info] [ubodt.cpp:236] Read rows 26000000
# [2022-07-15 01:51:46.127] [info] [ubodt.cpp:236] Read rows 27000000
# [2022-07-15 01:51:46.671] [info] [ubodt.cpp:236] Read rows 28000000
# [2022-07-15 01:51:47.224] [info] [ubodt.cpp:236] Read rows 29000000
# [2022-07-15 01:51:47.774] [info] [ubodt.cpp:236] Read rows 30000000
# [2022-07-15 01:51:48.323] [info] [ubodt.cpp:236] Read rows 31000000
# [2022-07-15 01:51:48.881] [info] [ubodt.cpp:236] Read rows 32000000
# ...
# [2022-07-15 02:13:03.164] [warning] [network.cpp:124] SRID is not found, set to 4326 by default
# [2022-07-15 02:13:03.414] [info] [network.cpp:170] Number of edges 215620 nodes 109070
# [2022-07-15 02:13:03.414] [info] [network.cpp:171] Field index: id 0 source 1 target 2
# [2022-07-15 02:13:03.531] [info] [network.cpp:174] Read network done.
# [2022-07-15 02:13:12.113] [info] [network_graph.cpp:17] Construct graph from network edges start
# [2022-07-15 02:13:12.126] [info] [network_graph.cpp:30] Graph nodes 109070 edges 215620
# [2022-07-15 02:13:12.126] [info] [network_graph.cpp:31] Construct graph from network edges end
# [2022-07-15 02:13:12.127] [info] [ubodt_gen_algorithm.cpp:76] Start to generate UBODT with delta 0.02
# [2022-07-15 02:13:12.127] [info] [ubodt_gen_algorithm.cpp:77] Output format csv
# [2022-07-15 02:13:20.081] [info] [ubodt_gen_algorithm.cpp:105] Progress 10907 / 109070
# [2022-07-15 02:13:28.031] [info] [ubodt_gen_algorithm.cpp:105] Progress 21814 / 109070
# [2022-07-15 02:13:36.655] [info] [ubodt_gen_algorithm.cpp:105] Progress 32721 / 109070
# [2022-07-15 02:13:44.921] [info] [ubodt_gen_algorithm.cpp:105] Progress 43628 / 109070
# [2022-07-15 02:13:52.405] [info] [ubodt_gen_algorithm.cpp:105] Progress 54535 / 109070
# [2022-07-15 02:14:00.161] [info] [ubodt_gen_algorithm.cpp:105] Progress 65442 / 109070
# [2022-07-15 02:14:07.496] [info] [ubodt_gen_algorithm.cpp:105] Progress 76349 / 109070
# [2022-07-15 02:14:15.713] [info] [ubodt_gen_algorithm.cpp:105] Progress 87256 / 109070
# [2022-07-15 02:14:24.595] [info] [ubodt_gen_algorithm.cpp:105] Progress 98163 / 109070
# [2022-07-15 02:14:35.325] [info] [ubodt.cpp:208] Reading UBODT file (CSV format) from /tmp/tmp7s4b8ajg
# [2022-07-15 02:14:35.897] [info] [ubodt.cpp:236] Read rows 1000000
# [2022-07-15 02:14:36.459] [info] [ubodt.cpp:236] Read rows 2000000
# [2022-07-15 02:14:37.016] [info] [ubodt.cpp:236] Read rows 3000000
# [2022-07-15 02:14:37.576] [info] [ubodt.cpp:236] Read rows 4000000
# [2022-07-15 02:14:38.138] [info] [ubodt.cpp:236] Read rows 5000000
# [2022-07-15 02:14:38.696] [info] [ubodt.cpp:236] Read rows 6000000
# [2022-07-15 02:14:39.261] [info] [ubodt.cpp:236] Read rows 7000000
# [2022-07-15 02:14:39.817] [info] [ubodt.cpp:236] Read rows 8000000
# [2022-07-15 02:14:40.371] [info] [ubodt.cpp:236] Read rows 9000000
# [2022-07-15 02:14:40.926] [info] [ubodt.cpp:236] Read rows 10000000
# [2022-07-15 02:14:41.477] [info] [ubodt.cpp:236] Read rows 11000000
# [2022-07-15 02:14:42.030] [info] [ubodt.cpp:236] Read rows 12000000
# [2022-07-15 02:14:42.580] [info] [ubodt.cpp:236] Read rows 13000000
# [2022-07-15 02:14:43.134] [info] [ubodt.cpp:236] Read rows 14000000
# [2022-07-15 02:14:43.688] [info] [ubodt.cpp:236] Read rows 15000000
# [2022-07-15 02:14:44.248] [info] [ubodt.cpp:236] Read rows 16000000
# [2022-07-15 02:14:44.806] [info] [ubodt.cpp:236] Read rows 17000000
# [2022-07-15 02:14:45.360] [info] [ubodt.cpp:236] Read rows 18000000
# [2022-07-15 02:14:45.916] [info] [ubodt.cpp:236] Read rows 19000000
# [2022-07-15 02:14:46.472] [info] [ubodt.cpp:236] Read rows 20000000
# [2022-07-15 02:14:47.031] [info] [ubodt.cpp:236] Read rows 21000000
# [2022-07-15 02:14:47.585] [info] [ubodt.cpp:236] Read rows 22000000
# [2022-07-15 02:14:48.137] [info] [ubodt.cpp:236] Read rows 23000000
# [2022-07-15 02:14:48.689] [info] [ubodt.cpp:236] Read rows 24000000
# [2022-07-15 02:14:49.244] [info] [ubodt.cpp:236] Read rows 25000000
# [2022-07-15 02:14:49.798] [info] [ubodt.cpp:236] Read rows 26000000
# [2022-07-15 02:14:50.367] [info] [ubodt.cpp:236] Read rows 27000000
# [2022-07-15 02:14:50.937] [info] [ubodt.cpp:236] Read rows 28000000
# [2022-07-15 02:14:51.500] [info] [ubodt.cpp:236] Read rows 29000000
# [2022-07-15 02:14:52.073] [info] [ubodt.cpp:236] Read rows 30000000
# [2022-07-15 02:14:52.645] [info] [ubodt.cpp:236] Read rows 31000000
# [2022-07-15 02:14:53.210] [info] [ubodt.cpp:236] Read rows 32000000
# [2022-07-15 02:14:53.770] [info] [ubodt.cpp:236] Read rows 33000000
# [2022-07-15 02:14:54.322] [info] [ubodt.cpp:236] Read rows 34000000
# [2022-07-15 02:14:54.875] [info] [ubodt.cpp:236] Read rows 35000000
# [2022-07-15 02:14:55.432] [info] [ubodt.cpp:236] Read rows 36000000
# [2022-07-15 02:14:55.989] [info] [ubodt.cpp:236] Read rows 37000000
# [2022-07-15 02:14:56.548] [info] [ubodt.cpp:236] Read rows 38000000
# [2022-07-15 02:14:57.106] [info] [ubodt.cpp:236] Read rows 39000000
# [2022-07-15 02:14:57.661] [info] [ubodt.cpp:236] Read rows 40000000
# [2022-07-15 02:14:58.221] [info] [ubodt.cpp:236] Read rows 41000000
# [2022-07-15 02:14:58.778] [info] [ubodt.cpp:236] Read rows 42000000
# [2022-07-15 02:14:59.354] [info] [ubodt.cpp:236] Read rows 43000000
# [2022-07-15 02:14:59.917] [info] [ubodt.cpp:236] Read rows 44000000
# [2022-07-15 02:15:00.479] [info] [ubodt.cpp:236] Read rows 45000000
# [2022-07-15 02:15:01.043] [info] [ubodt.cpp:236] Read rows 46000000
# [2022-07-15 02:15:01.600] [info] [ubodt.cpp:236] Read rows 47000000
# [2022-07-15 02:15:02.158] [info] [ubodt.cpp:236] Read rows 48000000
# [2022-07-15 02:15:02.713] [info] [ubodt.cpp:236] Read rows 49000000
# [2022-07-15 02:15:03.277] [info] [ubodt.cpp:236] Read rows 50000000
# [2022-07-15 02:15:03.833] [info] [ubodt.cpp:236] Read rows 51000000
# [2022-07-15 02:15:04.397] [info] [ubodt.cpp:236] Read rows 52000000
# [2022-07-15 02:15:04.974] [info] [ubodt.cpp:236] Read rows 53000000
# [2022-07-15 02:15:05.531] [info] [ubodt.cpp:236] Read rows 54000000
# [2022-07-15 02:15:06.094] [info] [ubodt.cpp:236] Read rows 55000000
# [2022-07-15 02:15:06.650] [info] [ubodt.cpp:236] Read rows 56000000
# [2022-07-15 02:15:07.209] [info] [ubodt.cpp:236] Read rows 57000000
# [2022-07-15 02:15:07.768] [info] [ubodt.cpp:236] Read rows 58000000
# [2022-07-15 02:15:08.329] [info] [ubodt.cpp:236] Read rows 59000000
# [2022-07-15 02:15:08.880] [info] [ubodt.cpp:236] Read rows 60000000
# [2022-07-15 02:15:09.444] [info] [ubodt.cpp:236] Read rows 61000000
# [2022-07-15 02:15:10.007] [info] [ubodt.cpp:236] Read rows 62000000
# [2022-07-15 02:15:10.563] [info] [ubodt.cpp:236] Read rows 63000000
# [2022-07-15 02:15:11.117] [info] [ubodt.cpp:236] Read rows 64000000
# [2022-07-15 02:15:11.675] [info] [ubodt.cpp:236] Read rows 65000000
# [2022-07-15 02:15:12.232] [info] [ubodt.cpp:236] Read rows 66000000
# [2022-07-15 02:15:12.779] [info] [ubodt.cpp:236] Read rows 67000000
# [2022-07-15 02:15:13.325] [info] [ubodt.cpp:236] Read rows 68000000
# [2022-07-15 02:15:13.873] [info] [ubodt.cpp:236] Read rows 69000000
# [2022-07-15 02:15:14.424] [info] [ubodt.cpp:236] Read rows 70000000
# [2022-07-15 02:15:14.973] [info] [ubodt.cpp:236] Read rows 71000000
# [2022-07-15 02:15:15.522] [info] [ubodt.cpp:236] Read rows 72000000
# [2022-07-15 02:15:16.069] [info] [ubodt.cpp:236] Read rows 73000000
# [2022-07-15 02:15:16.618] [info] [ubodt.cpp:236] Read rows 74000000
# [2022-07-15 02:15:17.167] [info] [ubodt.cpp:236] Read rows 75000000
# [2022-07-15 02:15:17.715] [info] [ubodt.cpp:236] Read rows 76000000
# [2022-07-15 02:15:18.264] [info] [ubodt.cpp:236] Read rows 77000000
# [2022-07-15 02:15:18.814] [info] [ubodt.cpp:236] Read rows 78000000
# [2022-07-15 02:15:19.374] [info] [ubodt.cpp:236] Read rows 79000000
# [2022-07-15 02:15:19.931] [info] [ubodt.cpp:236] Read rows 80000000
# [2022-07-15 02:15:20.491] [info] [ubodt.cpp:236] Read rows 81000000
# [2022-07-15 02:15:21.044] [info] [ubodt.cpp:236] Read rows 82000000
# [2022-07-15 02:15:21.595] [info] [ubodt.cpp:236] Read rows 83000000
# [2022-07-15 02:15:22.143] [info] [ubodt.cpp:236] Read rows 84000000
# [2022-07-15 02:15:22.692] [info] [ubodt.cpp:236] Read rows 85000000
# [2022-07-15 02:15:23.235] [info] [ubodt.cpp:236] Read rows 86000000
# [2022-07-15 02:15:23.782] [info] [ubodt.cpp:236] Read rows 87000000
# [2022-07-15 02:15:24.333] [info] [ubodt.cpp:236] Read rows 88000000
# [2022-07-15 02:15:24.890] [info] [ubodt.cpp:236] Read rows 89000000
# [2022-07-15 02:15:25.445] [info] [ubodt.cpp:236] Read rows 90000000
# [2022-07-15 02:15:26.005] [info] [ubodt.cpp:236] Read rows 91000000
# [2022-07-15 02:15:26.559] [info] [ubodt.cpp:236] Read rows 92000000
# [2022-07-15 02:15:27.109] [info] [ubodt.cpp:236] Read rows 93000000
# [2022-07-15 02:15:27.652] [info] [ubodt.cpp:236] Read rows 94000000
# [2022-07-15 02:15:28.196] [info] [ubodt.cpp:236] Read rows 95000000
# [2022-07-15 02:15:28.736] [info] [ubodt.cpp:236] Read rows 96000000
# [2022-07-15 02:15:28.765] [warning] [ubodt.cpp:242] Load factor is too large.
# [2022-07-15 02:15:28.765] [info] [ubodt.cpp:243] Finish reading UBODT with rows 96053977
# [2022-07-15 02:15:29.005] [info] [gps_reader.cpp:337] GPS data in trajectory shapefile format
# [2022-07-15 02:15:29.005] [info] [gps_reader.cpp:45] Read trajectory from file /tmp/tmpdw6lv9ov.shp
# [2022-07-15 02:15:29.005] [warning] [gps_reader.cpp:69] Timestamp column timestamp not found
# [2022-07-15 02:15:29.005] [info] [gps_reader.cpp:81] Total number of trajectories 2321
# [2022-07-15 02:15:29.005] [info] [gps_reader.cpp:82] Finish reading meta data
# Progress 1000
# Progress 2000
# [2022-07-15 02:16:01.862] [warning] [fmm_algorithm.cpp:289] Traj 1157 unmatched as point 0 and 1 not connected
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 24>()
#      20 # This is the best scheduler to use when doing I/O operations (which FMM requires)
#      23 sim1_results[:3]
# ---> 24 sim1_results = dask.compute(*sim1_results, scheduler='sync')
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:554, in get_sync(dsk, keys, **kwargs)
#     549 """A naive synchronous version of get_async
#     550
#     551 Can be useful for debugging.
#     552 """
#     553 kwargs.pop("num_workers", None)  # if num_workers present, remove it
# --> 554 return get_async(
#     555     synchronous_executor.submit,
#     556     synchronous_executor._max_workers,
#     557     dsk,
#     558     keys,
#     559     **kwargs,
#     560 )
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:497, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     495 while state["waiting"] or state["ready"] or state["running"]:
#     496     fire_tasks(chunksize)
# --> 497     for key, res_info, failed in queue_get(queue).result():
#     498         if failed:
#     499             exc, tb = loads(res_info)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:539, in SynchronousExecutor.submit(self, fn, *args, **kwargs)
#     537 fut = Future()
#     538 try:
# --> 539     fut.set_result(fn(*args, **kwargs))
#     540 except BaseException as e:
#     541     fut.set_exception(e)
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:235, in batch_execute_tasks(it)
#     231 def batch_execute_tasks(it):
#     232     """
#     233     Batch computing of multiple tasks with `execute_task`
#     234     """
# --> 235     return [execute_task(*a) for a in it]
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:235, in <listcomp>(.0)
#     231 def batch_execute_tasks(it):
#     232     """
#     233     Batch computing of multiple tasks with `execute_task`
#     234     """
# --> 235     return [execute_task(*a) for a in it]
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:226, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     224     failed = False
#     225 except BaseException as e:
# --> 226     result = pack_exception(e, dumps)
#     227     failed = True
#     228 return key, result, failed
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:221, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     219 try:
#     220     task, data = loads(task_info)
# --> 221     result = _execute_task(task, data)
#     222     id = get_id()
#     223     result = dumps((result, id))
#
# File ~/.local/lib/python3.10/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/.local/lib/python3.10/site-packages/dask/utils.py:41, in apply(func, args, kwargs)
#      39 def apply(func, args, kwargs=None):
#      40     if kwargs:
# ---> 41         return func(*args, **kwargs)
#      42     else:
#      43         return func(*args)
#
# File ~/G-RIPS-2022-Mitsubishi-A/Code/algorithms/fmm_bin.py:182, in FMM.run(self, input_edges, input_nodes, network_edges, network_nodes, return_results)
#     179 resultdf = pd.read_csv(tmp4.name + '.csv', sep=";")
#     181 # Extract cpath as list of int
# --> 182 resultdf["cpath_list"] = resultdf.apply(lambda row: extract_cpath(row.cpath), axis=1)
#     184 # Extract all the edges matched
#     185 all_edge_ids = np.unique(np.hstack(resultdf.cpath_list)).tolist()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# File ~/G-RIPS-2022-Mitsubishi-A/Code/algorithms/fmm_bin.py:182, in FMM.run.<locals>.<lambda>(row)
#     179 resultdf = pd.read_csv(tmp4.name + '.csv', sep=";")
#     181 # Extract cpath as list of int
# --> 182 resultdf["cpath_list"] = resultdf.apply(lambda row: extract_cpath(row.cpath), axis=1)
#     184 # Extract all the edges matched
#     185 all_edge_ids = np.unique(np.hstack(resultdf.cpath_list)).tolist()
#
# File ~/G-RIPS-2022-Mitsubishi-A/Code/algorithms/fmm_bin.py:56, in extract_cpath(cpath)
#      54 if (cpath==''):
#      55     return []
# ---> 56 return [int(s) for s in cpath.split(',')]
#
# AttributeError: 'float' object has no attribute 'split'

# %% [markdown]
# Now we iterate through our results, and evaluate it using the build-in evaluation method in mm_utils.

# %%
errors = []
for i in range(len(sim1_results)):
#    errors.append(dask.delayed(mm_utils.evaluate)(sim1_results[i],gt[i], matchid = "index")) # A more standard match method would be 'geometry', but in this case index is more reliable
# For whatever reason, delayed isn't working here, so I'm just going to do this manually
    errors.append(mm_utils.evaluate(sim1_results[i],
                                    gt[i].compute()[0],
                                    matchid = "index")) # A more standard match method would be 'geometry', but in this case index is more reliable

#errors = [dask.compute(*errors)]
    
#sim2.run(input_nodes = df_nodes, input_edges = df_edges, network_nodes = networknodes, network_edges = networkedges) # FMM doesn't consider input nodes or network nodes, so the inclusion here is superfluous
#pred_nodes, pred_edges = sim2.results
# I did implement plot() and evaluate() for sim2
# But for demonstration, I will use mm_utils, as some programmers may choose to not implement it themselves
#sim2.plot()
#sim2.evaluate()
#mm_utils.plot(network, df_nodes.append(df_edges), sim2.results())
#mm_utils.evaluate(sim2.results(), ground_truth, match='index'
# Out:
# /home/gjgress/.local/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/lib/python3.10/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#
# File ~/.local/lib/python3.10/site-packages/dask/delayed.py:597, in Delayed.__bool__(self)
#     596 def __bool__(self):
# --> 597     raise TypeError("Truth of Delayed objects is not supported")
#
# TypeError: Truth of Delayed objects is not supported
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/G-RIPS-2022-Mitsubishi-A/Code/algorithms/mm_utils.py:84, in evaluate(prediction, gt, matchid)
#      83 try:
# ---> 84     np.intersect1d(gt[matchid], prediction[matchid], return_indices=True)
#      85 except:
#
# File <__array_function__ internals>:180, in intersect1d(*args, **kwargs)
#
# File /usr/lib/python3.10/site-packages/numpy/lib/arraysetops.py:448, in intersect1d(ar1, ar2, assume_unique, return_indices)
#     447 if return_indices:
# --> 448     aux_sort_indices = np.argsort(aux, kind='mergesort')
#     449     aux = aux[aux_sort_indices]
#
# File <__array_function__ internals>:180, in argsort(*args, **kwargs)
#
# File /usr/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1120, in argsort(a, axis, kind, order)
#    1014 """
#    1015 Returns the indices that would sort an array.
#    1016
#    (...)
#    1118
#    1119 """
# -> 1120 return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#
# File /usr/lib/python3.10/site-packages/numpy/core/fromnumeric.py:66, in _wrapfunc(obj, method, *args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
# ---> 66     return _wrapit(obj, method, *args, **kwds)
#
# File /usr/lib/python3.10/site-packages/numpy/core/fromnumeric.py:43, in _wrapit(obj, method, *args, **kwds)
#      42     wrap = None
# ---> 43 result = getattr(asarray(obj), method)(*args, **kwds)
#      44 if wrap:
#
# File ~/.local/lib/python3.10/site-packages/dask/delayed.py:597, in Delayed.__bool__(self)
#     596 def __bool__(self):
# --> 597     raise TypeError("Truth of Delayed objects is not supported")
#
# TypeError: Truth of Delayed objects is not supported
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 errors = []
#       2 for i in range(len(sim1_results)):
#       3 #    errors.append(dask.delayed(mm_utils.evaluate)(sim1_results[i],gt[i], matchid = "index")) # A more standard match method would be 'geometry', but in this case index is more reliable
#       4 # For whatever reason, delayed isn't working here, so I'm just going to do this manually
# ----> 5     errors.append(mm_utils.evaluate(sim1_results[i],
#       6                                     gt[i].compute()[0],
#       7                                     matchid = "index"))
#
# File ~/G-RIPS-2022-Mitsubishi-A/Code/algorithms/mm_utils.py:86, in evaluate(prediction, gt, matchid)
#      84     np.intersect1d(gt[matchid], prediction[matchid], return_indices=True)
#      85 except:
# ---> 86     raise Exception('Currently only array-like objects can be matched; please choose a different match column.')
#      87 else:
#      88     evalint = gt.loc[np.intersect1d(gt[matchid], prediction[matchid], return_indices=True)[1]]
#
# Exception: Currently only array-like objects can be matched; please choose a different match column.

# %%
fig = plt.figure(1)
plt.boxplot(errors,vert=False)
plt.title('FMM Error %s on ' 
          + str(n) 
          + ' test cases \n(Average error = ' 
          + str(np.average(errors)) + ')')
plt.show()

# %% [markdown]
# Overall, FMM seems to handle itself okay, with the exception of one huge outlier!
#
# (Note-- having an error above 100% is not a bug; the standard error formula is not upper-bounded, despite being a percentage)

# %% [markdown]
# Let's see a few examples of our results.

# %%
n = 5
fig, axs = plt.subplots(4,n, figsize=(24,16))

fig.suptitle('FMM Evaluations Visualized')

for i in range(n):
    netemp = ne[i].compute()[0]
    gttemp = gt[i].compute()[0]
    netemp.plot(ax=axs[0,i])
    tn[i].compute()[0].plot(ax=axs[0,i], color='black',markersize=2)
    netemp.plot(ax=axs[1,i])
    gttemp.plot(ax=axs[1,i], color='green')
    netemp.plot(ax=axs[2,i])
    sim1_results[i].plot(ax=axs[2,i], color= 'red')
    evalint = gttemp.loc[np.intersect1d(gttemp['index'], sim1_results[i]['index'], return_indices=True)[1]]
    evalxor = pd.concat([gttemp.overlay(evalint, how="difference"), sim1_results[i].overlay(evalint, how = "difference")])
    evalxor.plot(ax=axs[3,i], color='purple')
    axs[3,i].text(0.5, -0.5, 'Error: ' + str(errors[i]), size=10, ha= 'center', transform=axs[3,i].transAxes)

fig.legend(handles=[axs[0,0].collections[0],axs[0,0].collections[1],axs[1,0].collections[1],axs[2,0].collections[1],axs[3,0].collections[0]], labels = ['Road Network', 'GPS Datapoints', 'Ground Truth', 'Prediction', 'Difference between GT and Pred.'], loc = 'lower left')
plt.savefig("image.png",bbox_inches='tight',dpi=100) 
plt.subplots_adjust(hspace=0.5)
